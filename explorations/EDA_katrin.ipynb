# %% [markdown]
# ## Katrin Rylander
# #### Uppgift 2 - EDA av API
# #### Explorativ undersökning av följande enpoints:
# - v1/cryptocurrency/quotes/latest
# - v1/cryptocurrency/listings/latest

# %% [markdown]
# **CoinMarketCap ID Map**

# %%
from requests import Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json
from dotenv import load_dotenv
import os

load_dotenv()

API_KEY = os.getenv("COINMARKET_API")

url_map = "https://pro-api.coinmarketcap.com/v1/cryptocurrency/map"

headers = {
    "Accepts": "application/json",
    "X-CMC_PRO_API_KEY": API_KEY,
}


session = Session()
session.headers.update(headers)

try:
  response = session.get(url_map)
  data = json.loads(response.text)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

data
# Out:
# {'status': {'timestamp': '2025-02-12T13:07:38.400Z',
#   'error_code': 0,
#   'error_message': None,
#   'elapsed': 265,
#   'credit_count': 1,
#   'notice': None},
#  'data': [{'id': 1,
#    'rank': 1,
#    'name': 'Bitcoin',
#    'symbol': 'BTC',
#    'slug': 'bitcoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2010-07-13T00:05:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 2,
#    'rank': 18,
#    'name': 'Litecoin',
#    'symbol': 'LTC',
#    'slug': 'litecoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2013-04-28T18:45:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 3,
#    'rank': 958,
#    'name': 'Namecoin',
#    'symbol': 'NMC',
#    'slug': 'namecoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2013-04-28T18:45:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 4,
#    'rank': 5637,
#    'name': 'Terracoin',
#    'symbol': 'TRC',
#    'slug': 'terracoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2013-04-28T18:45:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 5,
#    'rank': 1025,
#    'name': 'Peercoin',
#    'symbol': 'PPC',
#    'slug': 'peercoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2013-04-28T18:45:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 6,
#    'rank': 9335,
#    'name': 'Novacoin',
#    'symbol': 'NVC',
#    'slug': 'novacoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2013-04-28T18:45:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 8,
#    'rank': 1872,
#    'name': 'Feathercoin',
#    'symbol': 'FTC',
#    'slug': 'feathercoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2013-05-03T03:25:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 10,
#    'rank': 9100,
#    'name': 'Freicoin',
#    'symbol': 'FRC',
#    'slug': 'freicoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2013-05-03T03:25:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 13,
#    'rank': 8678,
#    'name': 'Ixcoin',
#    'symbol': 'IXC',
#    'slug': 'ixcoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2013-05-08T05:20:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 16,
#    'rank': 8888,
#    'name': 'WorldCoin WDC',
#    'symbol': 'WDC',
#    'slug': 'worldcoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2013-05-22T03:20:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 18,
#    'rank': 5604,
#    'name': 'Digitalcoin',
#    'symbol': 'DGC',
#    'slug': 'digitalcoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2013-06-09T17:55:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 22,
#    'rank': 1373,
#    'name': 'Luckycoin',
#    'symbol': 'LKY',
#    'slug': 'luckycoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2024-10-17T09:30:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 25,
#    'rank': 2282,
#    'name': 'Goldcoin',
#    'symbol': 'GLC',
#    'slug': 'goldcoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2013-06-14T06:45:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 26,
#    'rank': 2247,
#    'name': 'Junkcoin',
#    'symbol': 'JKC',
#    'slug': 'junkcoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2024-11-26T07:30:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 35,
#    'rank': 1858,
#    'name': 'Phoenixcoin',
#    'symbol': 'PXC',
#    'slug': 'phoenixcoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2013-07-04T05:15:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 41,
#    'rank': 9336,
#    'name': 'Infinitecoin',
#    'symbol': 'IFC',
#    'slug': 'infinitecoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2013-07-10T13:25:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 42,
#    'rank': 1714,
#    'name': 'Primecoin',
#    'symbol': 'XPM',
#    'slug': 'primecoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2013-07-11T03:20:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 43,
#    'rank': 9337,
#    'name': 'Anoncoin',
#    'symbol': 'ANC',
#    'slug': 'anoncoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2013-07-15T01:30:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 45,
#    'rank': 9338,
#    'name': 'CasinoCoin',
#    'symbol': 'CSC',
#    'slug': 'casinocoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2018-01-16T00:00:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 52,
#    'rank': 4,
#    'name': 'XRP',
#    'symbol': 'XRP',
#    'slug': 'xrp',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2013-08-04T18:50:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 56,
#    'rank': 9339,
#    'name': 'Zetacoin',
#    'symbol': 'ZET',
#    'slug': 'zetacoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2013-09-11T01:45:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 61,
#    'rank': 9340,
#    'name': 'TagCoin',
#    'symbol': 'TAG',
#    'slug': 'tagcoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2013-11-05T13:30:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 66,
#    'rank': 9341,
#    'name': 'Nxt',
#    'symbol': 'NXT',
#    'slug': 'nxt',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2013-12-04T05:45:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 67,
#    'rank': 7652,
#    'name': 'Unobtanium',
#    'symbol': 'UNO',
#    'slug': 'unobtanium',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2013-12-21T18:15:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 72,
#    'rank': 2156,
#    'name': 'Deutsche eMark',
#    'symbol': 'DEM',
#    'slug': 'deutsche-emark',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2013-12-15T01:50:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 74,
#    'rank': 8,
#    'name': 'Dogecoin',
#    'symbol': 'DOGE',
#    'slug': 'dogecoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2013-12-15T14:40:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 77,
#    'rank': 1302,
#    'name': 'Diamond',
#    'symbol': 'DMD',
#    'slug': 'diamond',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2013-12-19T12:30:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 78,
#    'rank': 9155,
#    'name': 'HoboNickels',
#    'symbol': 'HBN',
#    'slug': 'hobonickels',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2013-12-20T13:30:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 83,
#    'rank': 7443,
#    'name': 'Omni',
#    'symbol': 'OMNI',
#    'slug': 'omni',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2013-12-24T23:35:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 87,
#    'rank': 2332,
#    'name': 'FedoraCoin',
#    'symbol': 'TIPS',
#    'slug': 'fedoracoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2013-12-31T16:15:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 90,
#    'rank': 2307,
#    'name': 'Dimecoin',
#    'symbol': 'DIME',
#    'slug': 'dimecoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-01-06T07:40:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 93,
#    'rank': 9342,
#    'name': '42-coin',
#    'symbol': '42',
#    'slug': '42-coin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-01-14T04:30:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 99,
#    'rank': 1547,
#    'name': 'Vertcoin',
#    'symbol': 'VTC',
#    'slug': 'vertcoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-01-20T05:25:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 109,
#    'rank': 290,
#    'name': 'DigiByte',
#    'symbol': 'DGB',
#    'slug': 'digibyte',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-02-06T13:10:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 118,
#    'rank': 7365,
#    'name': 'ReddCoin',
#    'symbol': 'RDD',
#    'slug': 'redd',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-02-10T00:55:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 122,
#    'rank': 7564,
#    'name': 'PotCoin',
#    'symbol': 'POT',
#    'slug': 'potcoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-02-10T04:20:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 128,
#    'rank': 9343,
#    'name': 'Maxcoin',
#    'symbol': 'MAX',
#    'slug': 'maxcoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-02-12T13:30:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 131,
#    'rank': 153,
#    'name': 'Dash',
#    'symbol': 'DASH',
#    'slug': 'dash',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-02-14T13:40:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 132,
#    'rank': 894,
#    'name': 'Counterparty',
#    'symbol': 'XCP',
#    'slug': 'counterparty',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-02-15T13:55:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 148,
#    'rank': 8783,
#    'name': 'Auroracoin',
#    'symbol': 'AUR',
#    'slug': 'auroracoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-02-27T05:30:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 154,
#    'rank': 4538,
#    'name': 'Marscoin',
#    'symbol': 'MARS',
#    'slug': 'marscoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-02-24T13:40:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 162,
#    'rank': 4106,
#    'name': 'Magic Internet Money',
#    'symbol': 'MIM',
#    'slug': 'magic-internet-money',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-03-12T05:25:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 170,
#    'rank': 9344,
#    'name': 'BlackCoin',
#    'symbol': 'BLK',
#    'slug': 'blackcoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-02-28T05:10:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 213,
#    'rank': 904,
#    'name': 'MonaCoin',
#    'symbol': 'MONA',
#    'slug': 'monacoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-03-20T05:05:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 215,
#    'rank': 9345,
#    'name': 'Rubycoin',
#    'symbol': 'RBY',
#    'slug': 'rubycoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-03-20T05:05:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 234,
#    'rank': 7607,
#    'name': 'e-Gulden',
#    'symbol': 'EFL',
#    'slug': 'e-gulden',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-03-26T12:40:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 258,
#    'rank': 675,
#    'name': 'Groestlcoin',
#    'symbol': 'GRS',
#    'slug': 'groestlcoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-04-11T20:45:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 260,
#    'rank': 9346,
#    'name': 'PetroDollar',
#    'symbol': 'XPD',
#    'slug': 'petrodollar',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-04-15T04:35:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 263,
#    'rank': 9347,
#    'name': 'PLNcoin',
#    'symbol': 'PLNC',
#    'slug': 'plncoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-04-15T04:35:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 268,
#    'rank': 982,
#    'name': 'WhiteCoin',
#    'symbol': 'XWC',
#    'slug': 'whitecoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-04-18T12:10:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 276,
#    'rank': 9348,
#    'name': 'Bitstar',
#    'symbol': 'BITS',
#    'slug': 'bitstar',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-04-23T12:00:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 278,
#    'rank': 9349,
#    'name': 'Quebecoin',
#    'symbol': 'QBC',
#    'slug': 'quebecoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-04-23T12:00:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 290,
#    'rank': 9350,
#    'name': 'BlueCoin',
#    'symbol': 'BLU',
#    'slug': 'bluecoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-04-28T03:20:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 291,
#    'rank': 8478,
#    'name': 'MaidSafeCoin',
#    'symbol': 'MAID',
#    'slug': 'maidsafecoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-04-28T03:20:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 293,
#    'rank': 2193,
#    'name': 'Bitcoin Plus',
#    'symbol': 'XBC',
#    'slug': 'bitcoin-plus',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-05-04T01:30:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 298,
#    'rank': 9351,
#    'name': 'NewYorkCoin',
#    'symbol': 'NYC',
#    'slug': 'newyorkcoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-05-06T12:15:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 316,
#    'rank': 9352,
#    'name': 'Dreamcoin',
#    'symbol': 'DRM',
#    'slug': 'dreamcoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-05-13T04:00:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 328,
#    'rank': 29,
#    'name': 'Monero',
#    'symbol': 'XMR',
#    'slug': 'monero',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-05-21T01:40:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 333,
#    'rank': 9251,
#    'name': 'Curecoin',
#    'symbol': 'CURE',
#    'slug': 'curecoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-05-26T18:10:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 360,
#    'rank': 9353,
#    'name': 'Motocoin',
#    'symbol': 'MOTO',
#    'slug': 'motocoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-06-03T12:45:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 362,
#    'rank': 2279,
#    'name': 'CloakCoin',
#    'symbol': 'CLOAK',
#    'slug': 'cloakcoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-06-07T00:05:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 367,
#    'rank': 9354,
#    'name': 'Coin2.1',
#    'symbol': 'C2',
#    'slug': 'coin2-1',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-06-08T14:20:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 372,
#    'rank': 1382,
#    'name': 'Bytecoin',
#    'symbol': 'BCN',
#    'slug': 'bytecoin-bcn',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-06-17T13:00:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 377,
#    'rank': 4321,
#    'name': 'Navcoin',
#    'symbol': 'NAV',
#    'slug': 'nav-coin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-06-12T11:40:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 389,
#    'rank': 9355,
#    'name': 'Startcoin',
#    'symbol': 'START',
#    'slug': 'startcoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-06-15T14:55:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 405,
#    'rank': 8399,
#    'name': 'DigitalNote',
#    'symbol': 'XDN',
#    'slug': 'digitalnote',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-06-24T12:55:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 416,
#    'rank': 2684,
#    'name': 'HempCoin',
#    'symbol': 'THC',
#    'slug': 'hempcoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-06-28T16:30:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 448,
#    'rank': 9356,
#    'name': 'Stealth',
#    'symbol': 'XST',
#    'slug': 'stealth',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2022-09-30T12:40:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 460,
#    'rank': 9357,
#    'name': 'Clams',
#    'symbol': 'CLAM',
#    'slug': 'clams',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-08-26T02:30:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 463,
#    'rank': 1544,
#    'name': 'BitShares',
#    'symbol': 'BTS',
#    'slug': 'bitshares',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-07-21T03:40:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 470,
#    'rank': 9358,
#    'name': 'Viacoin',
#    'symbol': 'VIA',
#    'slug': 'viacoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-07-18T12:20:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 501,
#    'rank': 9359,
#    'name': 'Cryptonite',
#    'symbol': 'XCN',
#    'slug': 'cryptonite',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-08-02T21:15:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 502,
#    'rank': 9360,
#    'name': 'Carboncoin',
#    'symbol': 'CARBON',
#    'slug': 'carboncoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-08-02T21:15:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 506,
#    'rank': 2008,
#    'name': 'CannabisCoin',
#    'symbol': 'CANN',
#    'slug': 'cannabiscoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-08-02T22:00:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 512,
#    'rank': 14,
#    'name': 'Stellar',
#    'symbol': 'XLM',
#    'slug': 'stellar',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-08-05T05:40:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 541,
#    'rank': 539,
#    'name': 'Syscoin',
#    'symbol': 'SYS',
#    'slug': 'syscoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-08-20T11:00:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 558,
#    'rank': 9361,
#    'name': 'Emercoin',
#    'symbol': 'EMC',
#    'slug': 'emercoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-08-23T21:20:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 572,
#    'rank': 9362,
#    'name': 'RabbitCoin',
#    'symbol': 'RBBT',
#    'slug': 'rabbitcoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-08-30T22:20:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 576,
#    'rank': 2511,
#    'name': 'GameCredits',
#    'symbol': 'GAME',
#    'slug': 'gamecredits',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-09-01T16:50:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': {'id': 1,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x63f88a2298a5c4aee3c216aa6d926b184a4b2437'}},
#   {'id': 597,
#    'rank': 9363,
#    'name': 'Opal',
#    'symbol': 'OPAL',
#    'slug': 'opal',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-09-13T17:10:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 601,
#    'rank': 3049,
#    'name': 'Acoin',
#    'symbol': 'ACOIN',
#    'slug': 'acoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-09-13T19:40:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 638,
#    'rank': 2422,
#    'name': 'Trollcoin',
#    'symbol': 'TROLL',
#    'slug': 'trollcoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-09-30T07:50:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 644,
#    'rank': 6274,
#    'name': 'GlobalBoost',
#    'symbol': 'BSTY',
#    'slug': 'globalboost-y',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-10-03T12:35:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 656,
#    'rank': 9364,
#    'name': 'Prime-XI',
#    'symbol': 'PXI',
#    'slug': 'prime-xi',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-10-04T20:50:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 659,
#    'rank': 2424,
#    'name': 'Bitswift',
#    'symbol': 'BITS',
#    'slug': 'bitswift',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-10-05T17:40:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 693,
#    'rank': 362,
#    'name': 'Verge',
#    'symbol': 'XVG',
#    'slug': 'verge',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-10-25T22:10:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 702,
#    'rank': 9365,
#    'name': 'SpreadCoin',
#    'symbol': 'SPR',
#    'slug': 'spreadcoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-10-26T23:20:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 703,
#    'rank': 9366,
#    'name': 'Rimbit',
#    'symbol': 'RBT',
#    'slug': 'rimbit',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-10-26T23:20:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 707,
#    'rank': 7346,
#    'name': 'Blocknet',
#    'symbol': 'BLOCK',
#    'slug': 'blocknet',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-11-01T21:15:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 720,
#    'rank': 9367,
#    'name': 'Crown',
#    'symbol': 'CRW',
#    'slug': 'crown',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-11-08T22:50:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 733,
#    'rank': 9368,
#    'name': 'Quotient',
#    'symbol': 'XQN',
#    'slug': 'quotient',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-11-23T20:05:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 760,
#    'rank': 8581,
#    'name': 'Okcash',
#    'symbol': 'OK',
#    'slug': 'okcash',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-12-14T03:25:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 764,
#    'rank': 9369,
#    'name': 'PayCoin',
#    'symbol': 'XPY',
#    'slug': 'paycoin2',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2014-12-16T05:30:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 788,
#    'rank': 1840,
#    'name': 'Circuits of Value',
#    'symbol': 'COVAL',
#    'slug': 'circuits-of-value',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2015-01-23T13:35:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': {'id': 1,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x3d658390460295fb963f54dc0899cfb1c30776df'}},
#   {'id': 789,
#    'rank': 9370,
#    'name': 'Nexus',
#    'symbol': 'NXS',
#    'slug': 'nexus',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2015-01-25T18:50:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 815,
#    'rank': 9371,
#    'name': 'Kobocoin',
#    'symbol': 'KOBO',
#    'slug': 'kobocoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2015-02-15T15:10:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 819,
#    'rank': 8707,
#    'name': 'Bean Cash',
#    'symbol': 'BITB',
#    'slug': 'bean-cash',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2015-02-18T13:15:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 825,
#    'rank': 3,
#    'name': 'Tether USDt',
#    'symbol': 'USDT',
#    'slug': 'tether',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2015-02-25T13:30:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': {'id': 1,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xdac17f958d2ee523a2206206994597c13d831ec7'}},
#   {'id': 831,
#    'rank': 9372,
#    'name': 'Wild Beast Block',
#    'symbol': 'WBB',
#    'slug': 'wild-beast-block',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2015-02-28T17:10:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 853,
#    'rank': 2526,
#    'name': 'LiteDoge',
#    'symbol': 'LDOGE',
#    'slug': 'litedoge',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2015-03-19T05:30:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 857,
#    'rank': 9373,
#    'name': 'SongCoin',
#    'symbol': 'SONG',
#    'slug': 'songcoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2015-03-23T01:55:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 859,
#    'rank': 9374,
#    'name': 'Woodcoin',
#    'symbol': 'LOG',
#    'slug': 'woodcoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2015-03-23T02:00:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 873,
#    'rank': 260,
#    'name': 'NEM',
#    'symbol': 'XEM',
#    'slug': 'nem',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2015-04-01T00:25:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 898,
#    'rank': 9375,
#    'name': 'Californium',
#    'symbol': 'CF',
#    'slug': 'californium',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2015-04-21T12:10:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 918,
#    'rank': 9376,
#    'name': 'Bubble',
#    'symbol': 'BUB',
#    'slug': 'bubble',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2015-05-07T03:00:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 921,
#    'rank': 9377,
#    'name': 'Universal Currency',
#    'symbol': 'UNIT',
#    'slug': 'universal-currency',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2015-05-07T03:00:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 934,
#    'rank': 9378,
#    'name': 'ParkByte',
#    'symbol': 'PKB',
#    'slug': 'parkbyte',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2015-05-19T00:30:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 938,
#    'rank': 9107,
#    'name': 'ARbit',
#    'symbol': 'ARB',
#    'slug': 'arbit',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2015-05-21T04:10:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 945,
#    'rank': 9379,
#    'name': 'Bata',
#    'symbol': 'BTA',
#    'slug': 'bata',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2015-05-29T11:40:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 948,
#    'rank': 9380,
#    'name': 'AudioCoin',
#    'symbol': 'ADC',
#    'slug': 'audiocoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2015-06-05T12:55:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 951,
#    'rank': 9381,
#    'name': 'Synergy',
#    'symbol': 'SNRG',
#    'slug': 'synergy',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2015-06-08T04:40:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 978,
#    'rank': 9382,
#    'name': 'Ratecoin',
#    'symbol': 'XRA',
#    'slug': 'ratecoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2015-06-26T12:30:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 986,
#    'rank': 9383,
#    'name': 'CrevaCoin',
#    'symbol': 'CREVA',
#    'slug': 'crevacoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2015-07-07T15:45:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 993,
#    'rank': 9384,
#    'name': 'BowsCoin',
#    'symbol': 'BSC',
#    'slug': 'bowscoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2015-07-13T20:35:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1004,
#    'rank': 9032,
#    'name': 'HNC COIN',
#    'symbol': 'HNC',
#    'slug': 'hnccoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2015-07-21T16:35:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1019,
#    'rank': 9385,
#    'name': 'Manna',
#    'symbol': 'MANNA',
#    'slug': 'manna',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2015-07-27T15:50:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1020,
#    'rank': 9386,
#    'name': 'Axiom',
#    'symbol': 'AXIOM',
#    'slug': 'axiom',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2015-07-30T03:00:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1027,
#    'rank': 2,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2015-08-07T14:45:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1032,
#    'rank': 9387,
#    'name': 'TransferCoin',
#    'symbol': 'TX',
#    'slug': 'transfercoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2015-08-21T02:05:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1033,
#    'rank': 9388,
#    'name': 'GuccioneCoin',
#    'symbol': 'GCC',
#    'slug': 'guccionecoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2015-08-21T02:05:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1035,
#    'rank': 5796,
#    'name': 'AmsterdamCoin',
#    'symbol': 'AMS',
#    'slug': 'amsterdamcoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2015-08-21T02:05:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1037,
#    'rank': 815,
#    'name': 'Agoras: Tau Net',
#    'symbol': 'AGRS',
#    'slug': 'agoras-tokens',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2015-08-24T02:45:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': {'id': 1,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x738865301a9b7dd80dc3666dd48cf034ec42bdda'}},
#   {'id': 1038,
#    'rank': 9389,
#    'name': 'Eurocoin',
#    'symbol': 'EUC',
#    'slug': 'eurocoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2015-08-24T02:45:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1042,
#    'rank': 229,
#    'name': 'Siacoin',
#    'symbol': 'SC',
#    'slug': 'siacoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2015-08-26T18:15:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1052,
#    'rank': 9390,
#    'name': 'VectorAI',
#    'symbol': 'VEC2',
#    'slug': 'vector',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2015-09-04T16:35:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1053,
#    'rank': 2901,
#    'name': 'Bolivarcoin',
#    'symbol': 'BOLI',
#    'slug': 'bolivarcoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2015-09-08T21:25:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1066,
#    'rank': 5126,
#    'name': 'Pakcoin',
#    'symbol': 'PAK',
#    'slug': 'pakcoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2015-09-15T20:00:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1082,
#    'rank': 9391,
#    'name': 'SIBCoin',
#    'symbol': 'SIB',
#    'slug': 'sibcoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2015-09-25T22:15:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1085,
#    'rank': 9392,
#    'name': 'Swing',
#    'symbol': 'SWING',
#    'slug': 'swing',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2015-09-28T15:40:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1090,
#    'rank': 9393,
#    'name': 'Save and Gain',
#    'symbol': 'SANDG',
#    'slug': 'save-and-gain',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2015-10-12T16:30:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1104,
#    'rank': 1217,
#    'name': 'Augur',
#    'symbol': 'REP',
#    'slug': 'augur',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2015-10-27T17:10:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': {'id': 1,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x1985365e9f78359a9B6AD760e32412f4a445E862'}},
#   {'id': 1106,
#    'rank': 2565,
#    'name': 'StrongHands',
#    'symbol': 'SHND',
#    'slug': 'stronghands',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2015-10-30T18:05:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1107,
#    'rank': 2582,
#    'name': 'PAC Protocol',
#    'symbol': 'PAC',
#    'slug': 'pac-protocol',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2015-11-02T21:55:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1120,
#    'rank': 9394,
#    'name': 'DraftCoin',
#    'symbol': 'DFT',
#    'slug': 'draftcoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2015-11-23T19:55:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1135,
#    'rank': 4249,
#    'name': 'ClubCoin',
#    'symbol': 'CLUB',
#    'slug': 'clubcoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2015-12-21T17:45:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1136,
#    'rank': 9395,
#    'name': 'Adzcoin',
#    'symbol': 'ADZ',
#    'slug': 'adzcoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2015-12-26T00:35:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1146,
#    'rank': 9396,
#    'name': 'AvatarCoin',
#    'symbol': 'AV',
#    'slug': 'avatarcoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2016-01-05T18:30:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1154,
#    'rank': 1477,
#    'name': 'Validity',
#    'symbol': 'VAL',
#    'slug': 'validity',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2016-01-18T07:50:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1155,
#    'rank': 9397,
#    'name': 'Litecred',
#    'symbol': 'LTCR',
#    'slug': 'litecred',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2016-01-21T15:55:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1156,
#    'rank': 9398,
#    'name': 'Yocoin',
#    'symbol': 'YOC',
#    'slug': 'yocoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2016-01-21T17:00:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1159,
#    'rank': 9399,
#    'name': 'SaluS',
#    'symbol': 'SLS',
#    'slug': 'salus',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2016-01-22T17:35:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1164,
#    'rank': 9400,
#    'name': 'Francs',
#    'symbol': 'FRN',
#    'slug': 'francs',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2016-01-31T08:40:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1165,
#    'rank': 9401,
#    'name': 'Evil Coin',
#    'symbol': 'EVIL',
#    'slug': 'evil-coin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2016-01-31T08:40:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1168,
#    'rank': 233,
#    'name': 'Decred',
#    'symbol': 'DCR',
#    'slug': 'decred',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2016-02-10T19:55:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1169,
#    'rank': 905,
#    'name': 'PIVX',
#    'symbol': 'PIVX',
#    'slug': 'pivx',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2016-02-13T21:10:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1175,
#    'rank': 9402,
#    'name': 'Rubies',
#    'symbol': 'RBIES',
#    'slug': 'rubies',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2016-02-22T19:10:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1185,
#    'rank': 2623,
#    'name': 'FreedomCoin',
#    'symbol': 'FREED',
#    'slug': 'freedomcoin-freed',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2016-03-01T05:55:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1191,
#    'rank': 3338,
#    'name': 'Memetic / PepeCoin',
#    'symbol': 'MEME',
#    'slug': 'memetic',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2016-03-14T07:30:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1194,
#    'rank': 9403,
#    'name': 'Independent Money System',
#    'symbol': 'IMS',
#    'slug': 'independent-money-system',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2016-03-18T23:05:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1200,
#    'rank': 2721,
#    'name': 'NevaCoin',
#    'symbol': 'NEVA',
#    'slug': 'nevacoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2016-03-22T20:00:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1209,
#    'rank': 9404,
#    'name': 'PosEx',
#    'symbol': 'PEX',
#    'slug': 'posex',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2016-04-04T22:20:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1210,
#    'rank': 9405,
#    'name': 'Cabbage',
#    'symbol': 'CAB',
#    'slug': 'cabbage',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2016-04-04T22:20:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1212,
#    'rank': 9406,
#    'name': 'MojoCoin',
#    'symbol': 'MOJO',
#    'slug': 'mojocoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2016-04-06T19:30:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1214,
#    'rank': 330,
#    'name': 'Lisk',
#    'symbol': 'LSK',
#    'slug': 'lisk',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2016-04-06T20:15:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1216,
#    'rank': 9407,
#    'name': 'EDRCoin',
#    'symbol': 'EDRC',
#    'slug': 'edrcoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2016-04-08T17:20:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1218,
#    'rank': 9408,
#    'name': 'PostCoin',
#    'symbol': 'POST',
#    'slug': 'postcoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2016-04-08T17:20:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1223,
#    'rank': 9409,
#    'name': 'BERNcash',
#    'symbol': 'BERN',
#    'slug': 'berncash',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2016-04-11T07:00:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1230,
#    'rank': 429,
#    'name': 'Steem',
#    'symbol': 'STEEM',
#    'slug': 'steem',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2016-04-18T16:15:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1244,
#    'rank': 9410,
#    'name': 'HiCoin',
#    'symbol': 'XHI',
#    'slug': 'hicoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2016-05-04T00:00:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1247,
#    'rank': 3093,
#    'name': 'AquariusCoin',
#    'symbol': 'ARCO',
#    'slug': 'aquariuscoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2016-05-04T00:00:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1248,
#    'rank': 9411,
#    'name': 'Bitcoin 21',
#    'symbol': 'XBTC21',
#    'slug': 'bitcoin-21',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2016-05-05T17:55:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1250,
#    'rank': 9412,
#    'name': 'Zurcoin',
#    'symbol': 'ZUR',
#    'slug': 'zurcoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2016-05-09T23:00:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1252,
#    'rank': 9413,
#    'name': '2GIVE',
#    'symbol': '2GIVE',
#    'slug': '2give',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2016-05-16T18:10:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1254,
#    'rank': 9414,
#    'name': 'PlatinumBAR',
#    'symbol': 'XPTX',
#    'slug': 'platinumbar',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2016-05-17T16:45:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1257,
#    'rank': 9415,
#    'name': 'LanaCoin',
#    'symbol': 'LANA',
#    'slug': 'lanacoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2016-05-18T22:30:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1259,
#    'rank': 9416,
#    'name': 'PonziCoin',
#    'symbol': 'PONZI',
#    'slug': 'ponzicoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2016-05-18T22:30:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1273,
#    'rank': 9417,
#    'name': 'Citadel',
#    'symbol': 'CTL',
#    'slug': 'citadel',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2016-06-02T14:45:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1274,
#    'rank': 271,
#    'name': 'Waves',
#    'symbol': 'WAVES',
#    'slug': 'waves',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2016-06-02T21:10:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1281,
#    'rank': 6377,
#    'name': 'ION',
#    'symbol': 'ION',
#    'slug': 'ion',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2016-06-08T22:10:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1282,
#    'rank': 9418,
#    'name': 'High Voltage',
#    'symbol': 'HVCO',
#    'slug': 'high-voltage',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2016-06-08T22:10:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1285,
#    'rank': 9419,
#    'name': 'GoldBlocks',
#    'symbol': 'GB',
#    'slug': 'goldblocks',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2016-06-14T17:15:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1291,
#    'rank': 9420,
#    'name': 'Comet',
#    'symbol': 'CMT',
#    'slug': 'comet',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2016-06-26T19:35:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1297,
#    'rank': 3469,
#    'name': 'ChessCoin',
#    'symbol': 'CHESS',
#    'slug': 'chesscoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2016-07-02T03:40:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1298,
#    'rank': 1705,
#    'name': 'LBRY Credits',
#    'symbol': 'LBC',
#    'slug': 'library-credits',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2016-07-07T05:20:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1299,
#    'rank': 2196,
#    'name': 'PUTinCoin',
#    'symbol': 'PUT',
#    'slug': 'putincoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2016-07-07T05:20:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1306,
#    'rank': 9421,
#    'name': 'Cryptojacks',
#    'symbol': 'CJ',
#    'slug': 'cryptojacks',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2016-07-11T19:10:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 1312,
#    'rank': 1294,
#    'name': 'Steem Dollars',
#    'symbol': 'SBD',
#    'slug': 'steem-dollars',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2016-07-18T20:50:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
# ...
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': {'id': 1,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xB1A30851E3f7d841b231B086479608e17198363A'}},
#   {'id': 5338,
#    'rank': 1355,
#    'name': 'Somnium Space Cubes',
#    'symbol': 'CUBE',
#    'slug': 'somnium-space-cubes',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2021-04-29T23:05:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': {'id': 1,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xdf801468a808a32656d2ed2d2d80b72a129739f4'}},
#   {'id': 5350,
#    'rank': 377,
#    'name': 'XPR Network',
#    'symbol': 'XPR',
#    'slug': 'proton',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2020-04-06T02:30:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 5354,
#    'rank': 2204,
#    'name': 'PEAKDEFI',
#    'symbol': 'PEAK',
#    'slug': 'peakdefi',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2020-03-23T02:30:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': {'id': 1,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x630d98424efe0ea27fb1b3ab7741907dffeaad78'}},
#   {'id': 5355,
#    'rank': 9554,
#    'name': 'Chainpay',
#    'symbol': 'CPAY',
#    'slug': 'chainpay',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2020-03-23T02:35:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': {'id': 47,
#     'name': 'Tron20',
#     'symbol': 'TRX',
#     'slug': 'tron',
#     'token_address': 'TFyfB5ggmPwVDs8kU2X9vPY7idzaNpaVno'}},
#   {'id': 5358,
#    'rank': 1984,
#    'name': 'IBStoken',
#    'symbol': 'IBS',
#    'slug': 'ibstoken',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2020-04-02T00:10:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': {'id': 25,
#     'name': 'Polygon',
#     'symbol': 'POL',
#     'slug': 'polygon-ecosystem-token',
#     'token_address': '0xB9dF5FDa1c435cD4017a1F1F9111996520b64439'}},
#   {'id': 5365,
#    'rank': 9555,
#    'name': 'Historia',
#    'symbol': 'HTA',
#    'slug': 'historia',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2020-03-24T04:05:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 5370,
#    'rank': 279,
#    'name': 'Hive',
#    'symbol': 'HIVE',
#    'slug': 'hive-blockchain',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2020-03-26T02:00:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 5375,
#    'rank': 5655,
#    'name': 'Hive Dollar',
#    'symbol': 'HBD',
#    'slug': 'hive-dollar',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2020-03-26T16:15:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 5380,
#    'rank': 658,
#    'name': 'Hunt Town',
#    'symbol': 'HUNT',
#    'slug': 'hunt',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2020-03-30T01:20:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': {'id': 1,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x9aab071b4129b083b01cb5a0cb513ce7eca26fa5'}},
#   {'id': 5382,
#    'rank': 748,
#    'name': 'ELYSIA',
#    'symbol': 'EL',
#    'slug': 'elysia',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2020-03-30T01:30:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': {'id': 1,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x2781246fe707bb15cee3e5ea354e2154a2877b16'}},
#   {'id': 5392,
#    'rank': 9556,
#    'name': 'Scopuly',
#    'symbol': 'SCOP',
#    'slug': 'scopuly-coin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2020-04-01T23:55:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': {'id': 27,
#     'name': 'Stellar',
#     'symbol': 'XLM',
#     'slug': 'stellar',
#     'token_address': 'GC6OYQJIZF3HFXCYPFCBXYXNGIBQ4TNSFUBUXQJOZWIP6F3YZK4QH3VQ'}},
#   {'id': 5397,
#    'rank': 2782,
#    'name': 'Castweet',
#    'symbol': 'CTT',
#    'slug': 'castweet',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2020-03-31T02:20:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': {'id': 1,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x1a4743cf1af4c289351390a2b3fe7c13d2f7c235'}},
#   {'id': 5399,
#    'rank': 8572,
#    'name': 'TILWIKI',
#    'symbol': 'TLW',
#    'slug': 'tilwiki',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2020-04-02T03:10:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': {'id': 1,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x06f3cdabae564b0546529b4dd8fef1bcd4235753'}},
#   {'id': 5401,
#    'rank': 9557,
#    'name': 'CoinLoan',
#    'symbol': 'CLT',
#    'slug': 'coinloan',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2020-08-01T00:15:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': {'id': 1,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x2001f2a0cf801ecfda622f6c28fb6e10d803d969'}},
#   {'id': 5407,
#    'rank': 2512,
#    'name': 'KingdomStarter',
#    'symbol': 'KDG',
#    'slug': 'kingdomstarter',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2020-04-02T04:55:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': {'id': 14,
#     'name': 'BNB Smart Chain (BEP20)',
#     'symbol': 'BNB',
#     'slug': 'bnb',
#     'token_address': '0x87a2d9a9a6b2d61b2a57798f1b4b2ddd19458fb6'}},
#   {'id': 5409,
#    'rank': 2703,
#    'name': '4P FOUR',
#    'symbol': 'FOUR',
#    'slug': '4thpillar-technologies',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2020-06-15T04:15:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': {'id': 1,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x4730fb1463a6f1f44aeb45f6c5c422427f37f4d0'}},
#   {'id': 5410,
#    'rank': 477,
#    'name': 'PARSIQ',
#    'symbol': 'PRQ',
#    'slug': 'parsiq',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2020-08-20T21:45:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': {'id': 1,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x362bc847A3a9637d3af6624EeC853618a43ed7D2'}},
#   {'id': 5423,
#    'rank': 1937,
#    'name': 'DSLA Protocol',
#    'symbol': 'DSLA',
#    'slug': 'dsla-protocol',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2020-04-09T23:40:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': {'id': 1,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x3affcca64c2a6f4e3b6bd9c64cd2c969efd1ecbe'}},
#   {'id': 5425,
#    'rank': 3101,
#    'name': 'Mesefa',
#    'symbol': 'SEFA',
#    'slug': 'mesefa',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2020-04-09T00:30:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': {'id': 1,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x27201232579491Ce9b116Ac6F37D354Cc723A2f3'}},
#   {'id': 5426,
#    'rank': 5,
#    'name': 'Solana',
#    'symbol': 'SOL',
#    'slug': 'solana',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2020-04-10T04:55:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 5429,
#    'rank': 627,
#    'name': 'DEAPcoin',
#    'symbol': 'DEP',
#    'slug': 'deapcoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2020-04-10T05:10:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': {'id': 1,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x1a3496c18d558bd9c6c8f609e1b129f67ab08163'}},
#   {'id': 5434,
#    'rank': 10845,
#    'name': 'pTokens BTC',
#    'symbol': 'pBTC',
#    'slug': 'ptokens-btc',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2020-04-12T16:30:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': {'id': 1,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x62199B909FB8B8cf870f97BEf2cE6783493c4908'}},
#   {'id': 5435,
#    'rank': 1077,
#    'name': 'Epic Cash',
#    'symbol': 'EPIC',
#    'slug': 'epic-cash',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2020-04-12T16:45:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 5437,
#    'rank': 9558,
#    'name': 'BIZZCOIN',
#    'symbol': 'BIZZ',
#    'slug': 'bizzcoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2020-04-12T17:10:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': {'id': 47,
#     'name': 'Tron20',
#     'symbol': 'TRX',
#     'slug': 'tron',
#     'token_address': 'TLZ1eA1KM7qgRk4VWQ9GyPHGDh4KdGrF7w'}},
#   {'id': 5444,
#    'rank': 392,
#    'name': 'Cartesi',
#    'symbol': 'CTSI',
#    'slug': 'cartesi',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2020-04-23T03:15:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': {'id': 1,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x491604c0fdf08347dd1fa4ee062a822a5dd06b5d'}},
#   {'id': 5445,
#    'rank': 3240,
#    'name': 'LBK',
#    'symbol': 'LBK',
#    'slug': 'lbk',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2020-04-14T22:25:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': {'id': 1,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x9cb1aeafcc8a9406632c5b084246ea72f62d37b6'}},
#   {'id': 5446,
#    'rank': 1076,
#    'name': 'USDJ',
#    'symbol': 'USDJ',
#    'slug': 'usdj',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2020-04-14T01:35:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': {'id': 47,
#     'name': 'Tron20',
#     'symbol': 'TRX',
#     'slug': 'tron',
#     'token_address': 'TMwFHYXLJaRUPeW6421aqXL4ZEzPRFGkGT'}},
#   {'id': 5450,
#    'rank': 5049,
#    'name': 'Wibx',
#    'symbol': 'WBX',
#    'slug': 'wibx',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2020-04-15T03:40:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': {'id': 1,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xbb97e381f1d1e94ffa2a5844f6875e6146981009'}},
#   {'id': 5453,
#    'rank': 1208,
#    'name': 'KardiaChain',
#    'symbol': 'KAI',
#    'slug': 'kardiachain',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2020-04-17T23:55:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': {'id': 1,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xD9Ec3ff1f8be459Bb9369b4E79e9Ebcf7141C093'}},
#   {'id': 5468,
#    'rank': 805,
#    'name': 'Isiklar Coin',
#    'symbol': 'ISIKC',
#    'slug': 'isiklar-coin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2020-04-16T00:45:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': {'id': 1,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x4339befb55cfa65344ef6f4bb7f05fae3458670a'}},
#   {'id': 5471,
#    'rank': 1830,
#    'name': 'Ghost',
#    'symbol': 'GHOST',
#    'slug': 'ghost',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2020-05-26T20:25:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 5473,
#    'rank': 3084,
#    'name': 'CRDT',
#    'symbol': 'CRDT',
#    'slug': 'crdt',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2020-07-24T21:30:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': {'id': 1,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xDaab5E695bb0E8Ce8384ee56BA38fA8290618e52'}},
#   {'id': 5474,
#    'rank': 8326,
#    'name': 'Ixinium',
#    'symbol': 'XXA',
#    'slug': 'ixinium',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2020-04-22T10:40:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 5478,
#    'rank': 3098,
#    'name': 'ECOSC',
#    'symbol': 'ECU',
#    'slug': 'ecosc',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2020-04-20T01:45:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': {'id': 1,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x8fc9b6354E839AB1c8B31F4afa53607092B8C2e5'}},
#   {'id': 5482,
#    'rank': 9559,
#    'name': 'CCX',
#    'symbol': 'CCXX',
#    'slug': 'counos-x',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2020-04-20T03:15:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 5486,
#    'rank': 9560,
#    'name': 'Jack Token',
#    'symbol': 'JACK',
#    'slug': 'jack-token',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2020-04-21T22:10:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': {'id': 1,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x4e12eb8e506ccd1427f6b8f7faa3e88fb698eb28'}},
#   {'id': 5488,
#    'rank': 148,
#    'name': 'JUST',
#    'symbol': 'JST',
#    'slug': 'just',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2020-05-07T14:30:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': {'id': 47,
#     'name': 'Tron20',
#     'symbol': 'TRX',
#     'slug': 'tron',
#     'token_address': 'TCFLL5dx5ZJdKnWuesXxi1VPwjLVmWZZy9'}},
#   {'id': 5513,
#    'rank': 5153,
#    'name': 'Crypto Holding Frank Token',
#    'symbol': 'CHFT',
#    'slug': 'crypto-holding-frank-token',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2020-05-11T23:35:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': {'id': 1,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x58002a6b6e659a16de9f02f529b10536e307b0d9'}},
#   {'id': 5518,
#    'rank': 6887,
#    'name': 'Torex',
#    'symbol': 'TOR',
#    'slug': 'torex',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2020-04-29T18:35:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': {'id': 1,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x9ea20fbfaa44efbc60c6728fcdba17f01b7e04fe'}},
#   {'id': 5520,
#    'rank': 3068,
#    'name': 'Martkist',
#    'symbol': 'MARTK',
#    'slug': 'martkist',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2020-05-18T23:05:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': None},
#   {'id': 5521,
#    'rank': 8060,
#    'name': 'EzyStayz',
#    'symbol': 'EZY',
#    'slug': 'ezystayz',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2020-04-29T23:35:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': {'id': 1,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xA6D5C720a9af5A405dFB6b9F44Fc44FaB5D4A58D'}},
#   {'id': 5522,
#    'rank': 1956,
#    'name': 'SENSO',
#    'symbol': 'SENSO',
#    'slug': 'senso',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2020-05-04T22:00:00.000Z',
#    'last_historical_data': '2025-02-12T12:55:00.000Z',
#    'platform': {'id': 1,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xc19b6a4ac7c7cc24459f08984bbd09664af17bd1'}},
#   ...]}

# %%
import pandas as pd

# Convert to DataFrame
df = pd.DataFrame(data["data"])

# %%
df.head()
# Out:
#    id  rank       name symbol       slug  is_active  status  \
# 0   1     1    Bitcoin    BTC    bitcoin          1       1
# 1   2    18   Litecoin    LTC   litecoin          1       1
# 2   3   958   Namecoin    NMC   namecoin          1       1
# 3   4  5637  Terracoin    TRC  terracoin          1       1
# 4   5  1025   Peercoin    PPC   peercoin          1       1
#
#       first_historical_data      last_historical_data platform
# 0  2010-07-13T00:05:00.000Z  2025-02-12T12:55:00.000Z     None
# 1  2013-04-28T18:45:00.000Z  2025-02-12T12:55:00.000Z     None
# 2  2013-04-28T18:45:00.000Z  2025-02-12T12:55:00.000Z     None
# 3  2013-04-28T18:45:00.000Z  2025-02-12T12:55:00.000Z     None
# 4  2013-04-28T18:45:00.000Z  2025-02-12T12:55:00.000Z     None

# %%
df_sorted = df.sort_values(by="rank", ascending=True)
df_sorted.head(10)
# Out:
#        id  rank         name symbol      slug  is_active  status  \
# 0       1     1      Bitcoin    BTC   bitcoin          1       1
# 117  1027     2     Ethereum    ETH  ethereum          1       1
# 97    825     3  Tether USDt   USDT    tether          1       1
# 19     52     4          XRP    XRP       xrp          1       1
# 977  5426     5       Solana    SOL    solana          1       1
# 282  1839     6          BNB    BNB       bnb          1       1
# 617  3408     7         USDC   USDC  usd-coin          1       1
# 25     74     8     Dogecoin   DOGE  dogecoin          1       1
# 324  2010     9      Cardano    ADA   cardano          1       1
# 309  1958    10         TRON    TRX      tron          1       1
#
#         first_historical_data      last_historical_data  \
# 0    2010-07-13T00:05:00.000Z  2025-02-12T12:55:00.000Z
# 117  2015-08-07T14:45:00.000Z  2025-02-12T12:55:00.000Z
# 97   2015-02-25T13:30:00.000Z  2025-02-12T12:55:00.000Z
# 19   2013-08-04T18:50:00.000Z  2025-02-12T12:55:00.000Z
# 977  2020-04-10T04:55:00.000Z  2025-02-12T12:55:00.000Z
# 282  2017-07-25T04:30:00.000Z  2025-02-12T12:55:00.000Z
# 617  2018-10-08T18:45:00.000Z  2025-02-12T12:55:00.000Z
# 25   2013-12-15T14:40:00.000Z  2025-02-12T12:55:00.000Z
# 324  2017-10-01T20:30:00.000Z  2025-02-12T12:55:00.000Z
# 309  2017-09-13T01:15:00.000Z  2025-02-12T12:55:00.000Z
#
#                                               platform
# 0                                                 None
# 117                                               None
# 97   {'id': 1, 'name': 'Ethereum', 'symbol': 'ETH',...
# 19                                                None
# 977                                               None
# 282                                               None
# 617  {'id': 1, 'name': 'Ethereum', 'symbol': 'ETH',...
# 25                                                None
# 324                                               None
# 309                                               None

# %% [markdown]
# **v1/cryptocurrency/quotes/latest**
# #### NOTE: Per our Best Practices we recommend utilizing CMC ID instead of cryptocurrency symbols to securely identify cryptocurrencies with our other endpoints and in your own application logic.

# %%
from requests import Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json
from dotenv import load_dotenv
import os

load_dotenv()

CMC_id = 1

API_KEY = os.getenv("COINMARKET_API")

url_end_quotes = 'v1/cryptocurrency/quotes/latest'

url_base = 'https://pro-api.coinmarketcap.com/' 

url = url_base + url_end_quotes

# %%
parameters = {
  'id': CMC_id,
  'convert': "SEK",
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': API_KEY,
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data_crypto_1 = json.loads(response.text)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %%
data_crypto_1
# Out:
# {'status': {'timestamp': '2025-02-12T13:54:14.547Z',
#   'error_code': 0,
#   'error_message': None,
#   'elapsed': 18,
#   'credit_count': 1,
#   'notice': None},
#  'data': {'1': {'id': 1,
#    'name': 'Bitcoin',
#    'symbol': 'BTC',
#    'slug': 'bitcoin',
#    'num_market_pairs': 11937,
#    'date_added': '2010-07-13T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'sha-256',
#     'store-of-value',
#     'state-channel',
#     'coinbase-ventures-portfolio',
#     'three-arrows-capital-portfolio',
#     'polychain-capital-portfolio',
#     'binance-labs-portfolio',
#     'blockchain-capital-portfolio',
#     'boostvc-portfolio',
#     'cms-holdings-portfolio',
#     'dcg-portfolio',
#     'dragonfly-capital-portfolio',
#     'electric-capital-portfolio',
#     'fabric-ventures-portfolio',
#     'framework-ventures-portfolio',
#     'galaxy-digital-portfolio',
#     'huobi-capital-portfolio',
#     'alameda-research-portfolio',
#     'a16z-portfolio',
#     '1confirmation-portfolio',
#     'winklevoss-capital-portfolio',
#     'usv-portfolio',
#     'placeholder-ventures-portfolio',
#     'pantera-capital-portfolio',
#     'multicoin-capital-portfolio',
#     'paradigm-portfolio',
#     'bitcoin-ecosystem',
#     'ftx-bankruptcy-estate',
#     '2017-2018-alt-season'],
#    'max_supply': 21000000,
#    'circulating_supply': 19823203,
#    'total_supply': 19823203,
#    'is_active': 1,
#    'infinite_supply': False,
#    'platform': None,
#    'cmc_rank': 1,
#    'is_fiat': 0,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-02-12T13:52:00.000Z',
#    'quote': {'SEK': {'price': 1037938.5583465723,
#      'volume_24h': 448179992465.3932,
#      'volume_change_24h': 28.5354,
#      'percent_change_1h': -1.42908556,
#      'percent_change_24h': -2.33942849,
#      'percent_change_7d': -3.87652615,
#      'percent_change_30d': 4.19716311,
#      'percent_change_60d': -6.28487801,
#      'percent_change_90d': 4.38653085,
#      'market_cap': 20575266743631.45,
#      'market_cap_dominance': 60.1909,
#      'fully_diluted_market_cap': 21796709725278.01,
#      'tvl': None,
#      'last_updated': '2025-02-12T13:53:03.000Z'}}}}}

# %% [markdown]
# **v1/cryptocurrency/listings/latest**

# %%
import requests
import pandas as pd
import json
from dotenv import load_dotenv
import os

load_dotenv()

API_KEY = os.getenv("COINMARKET_API")

URL = "https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest"

# Define headers for authentication
headers = {
    "Accepts": "application/json",
    "X-CMC_PRO_API_KEY": API_KEY,
}

# Define parameters (limit to top 10 for this example)
params = {
    "start": 1,  # Rank starting from 1
    "limit": 10,  # Get top 10 cryptocurrencies
    "convert": "SEK"  # Convert prices to SEK
}

# Fetch data from CoinMarketCap
response = requests.get(URL, headers=headers, params=params)
data = response.json()

# %%
# Extract useful metrics
crypto_list = []
for coin in data["data"]:
    quote = coin["quote"]["SEK"]
    crypto_list.append({
        "Rank": coin["cmc_rank"],
        "Name": coin["name"],
        "Symbol": coin["symbol"],
        "Price (SEK)": round(quote["price"], 4),
        "Market Cap (SEK)": round(quote["market_cap"], 2),
        "Fully Diluted Market Cap (SEK)": round(quote["fully_diluted_market_cap"], 2),
        "24h Volume (SEK)": round(quote["volume_24h"], 2),
        "Volume/Market Cap Ratio": round(quote["volume_24h"] / quote["market_cap"], 4),
        "Liquidity Score (%)": round(quote["volume_24h"] / quote["market_cap"] * 100, 2),
        "Circulating Supply": round(coin["circulating_supply"], 2),
        "Total Supply": round(coin["total_supply"], 2) if coin["total_supply"] else "N/A",
        "Max Supply": round(coin["max_supply"], 2) if coin["max_supply"] else "Unlimited",
        "Dominance (%)": round(quote["market_cap_dominance"], 2),
        "24h % Change": round(quote["percent_change_24h"], 2),
        "7d % Change": round(quote["percent_change_7d"], 2),
        "30d % Change": round(quote["percent_change_30d"], 2),
        "All-Time High (SEK)": round(quote["price"] / (1 - quote["percent_change_24h"] / 100), 4)
    })

# %%
# Convert to a Pandas DataFrame
df_top10 = pd.DataFrame(crypto_list)

# Display the DataFrame
df_top10
# Out:
#    Rank         Name Symbol   Price (SEK)  Market Cap (SEK)  \
# 0     1      Bitcoin    BTC  1.041637e+06      2.064858e+13
# 1     2     Ethereum    ETH  2.835574e+04      3.418088e+12
# 2     3  Tether USDt   USDT  1.094470e+01      1.553636e+12
# 3     4          XRP    XRP  2.610000e+01      1.507604e+12
# 4     5       Solana    SOL  2.102956e+03      1.026630e+12
# 5     6          BNB    BNB  7.005445e+03      9.981313e+11
# 6     7         USDC   USDC  1.094530e+01      6.140365e+11
# 7     8     Dogecoin   DOGE  2.759100e+00      4.083867e+11
# 8     9      Cardano    ADA  8.415500e+00      2.962007e+11
# 9    10         TRON    TRX  2.638300e+00      2.271628e+11
#
#    Fully Diluted Market Cap (SEK)  24h Volume (SEK)  Volume/Market Cap Ratio  \
# 0                    2.187438e+13      4.479161e+11                   0.0217
# 1                    3.418088e+12      2.517515e+11                   0.0737
# 2                    1.571337e+12      9.512884e+11                   0.6123
# 3                    2.610003e+12      5.819334e+10                   0.0386
# 4                    1.249000e+12      3.779922e+10                   0.0368
# 5                    9.981313e+11      2.307537e+10                   0.0231
# 6                    6.140365e+11      8.768488e+10                   0.1428
# 7                    4.083867e+11      1.757503e+10                   0.0430
# 8                    3.786958e+11      1.534485e+10                   0.0518
# 9                    2.271629e+11      6.924053e+09                   0.0305
#
#    Liquidity Score (%)  Circulating Supply  Total Supply    Max Supply  \
# 0                 2.17        1.982320e+07  1.982320e+07      21000000
# 1                 7.37        1.205431e+08  1.205431e+08     Unlimited
# 2                61.23        1.419533e+11  1.435706e+11     Unlimited
# 3                 3.86        5.776255e+10  9.998650e+10  100000000000
# 4                 3.68        4.881843e+08  5.939260e+08     Unlimited
# 5                 2.31        1.424794e+08  1.424794e+08     Unlimited
# 6                14.28        5.610054e+10  5.610054e+10     Unlimited
# 7                 4.30        1.480154e+11  1.480154e+11     Unlimited
# 8                 5.18        3.519720e+10  4.499508e+10   45000000000
# 9                 3.05        8.610155e+10  8.610157e+10     Unlimited
#
#    Dominance (%)  24h % Change  7d % Change  30d % Change  All-Time High (SEK)
# 0          60.47         -1.64        -3.39          4.69         1.024837e+06
# 1          10.00         -2.24        -7.73        -14.99         2.773472e+04
# 2           4.55         -0.02        -0.03          0.10         1.094290e+01
# 3           4.42         -2.94        -5.82          0.56         2.535370e+01
# 4           3.00         -3.35        -6.59          9.48         2.034803e+03
# 5           2.92          1.09        11.03         -4.24         7.082310e+03
# 6           1.80          0.01         0.01          0.01         1.094610e+01
# 7           1.20         -2.22        -5.73        -20.61         2.699200e+00
# 8           0.87         -2.75        -0.26        -14.83         8.190500e+00
# 9           0.66         -1.68         6.66          9.44         2.594600e+00

# %%
# Save to CSV (optional)
df_top10.to_csv("crypto_data_top10.csv", index=False)
print("Data saved to crypto_data.csv ✅")
# Out:
# Data saved to crypto_data.csv ✅
