# %%
import dotenv
import os
from requests import Session
from pprint import pprint

dotenv.load_dotenv()

API_KEY = os.getenv("COINMARKETCAP_API_KEY")
API_ENDPOINT = " https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest"

s = Session()

response_api = s.get(
    url=API_ENDPOINT,
    headers={"Accepts": "application/json", "X-CMC_PRO_API_KEY": API_KEY},
)

data = response_api.json()

pprint(data)
# Out:
# {'data': [{'circulating_supply': 19822912,
#            'cmc_rank': 1,
#            'date_added': '2010-07-13T00:00:00.000Z',
#            'id': 1,
#            'infinite_supply': False,
#            'last_updated': '2025-02-11T19:32:00.000Z',
#            'max_supply': 21000000,
#            'name': 'Bitcoin',
#            'num_market_pairs': 11931,
#            'platform': None,
#            'quote': {'USD': {'fully_diluted_market_cap': 1997722769053.91,
#                              'last_updated': '2025-02-11T19:32:00.000Z',
#                              'market_cap': 1885746792921.5217,
#                              'market_cap_dominance': 60.3266,
#                              'percent_change_1h': -0.64581622,
#                              'percent_change_24h': -2.5375842,
#                              'percent_change_30d': 0.44837373,
#                              'percent_change_60d': -6.14327796,
#                              'percent_change_7d': -5.36679904,
#                              'percent_change_90d': 4.7418409,
#                              'price': 95129.65566923375,
#                              'tvl': None,
#                              'volume_24h': 33047141317.35391,
#                              'volume_change_24h': -25.2786}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'bitcoin',
#            'symbol': 'BTC',
#            'tags': ['mineable',
#                     'pow',
#                     'sha-256',
#                     'store-of-value',
#                     'state-channel',
#                     'coinbase-ventures-portfolio',
#                     'three-arrows-capital-portfolio',
#                     'polychain-capital-portfolio',
#                     'binance-labs-portfolio',
#                     'blockchain-capital-portfolio',
#                     'boostvc-portfolio',
#                     'cms-holdings-portfolio',
#                     'dcg-portfolio',
#                     'dragonfly-capital-portfolio',
#                     'electric-capital-portfolio',
#                     'fabric-ventures-portfolio',
#                     'framework-ventures-portfolio',
#                     'galaxy-digital-portfolio',
#                     'huobi-capital-portfolio',
#                     'alameda-research-portfolio',
#                     'a16z-portfolio',
#                     '1confirmation-portfolio',
#                     'winklevoss-capital-portfolio',
#                     'usv-portfolio',
#                     'placeholder-ventures-portfolio',
#                     'pantera-capital-portfolio',
#                     'multicoin-capital-portfolio',
#                     'paradigm-portfolio',
#                     'bitcoin-ecosystem',
#                     'ftx-bankruptcy-estate',
#                     '2017-2018-alt-season'],
#            'total_supply': 19822912,
#            'tvl_ratio': None},
#           {'circulating_supply': 120540713.49245739,
#            'cmc_rank': 2,
#            'date_added': '2015-08-07T00:00:00.000Z',
#            'id': 1027,
#            'infinite_supply': True,
#            'last_updated': '2025-02-11T19:33:00.000Z',
#            'max_supply': None,
#            'name': 'Ethereum',
#            'num_market_pairs': 9923,
#            'platform': None,
#            'quote': {'USD': {'fully_diluted_market_cap': 313364736303.9,
#                              'last_updated': '2025-02-11T19:33:00.000Z',
#                              'market_cap': 313364736303.8974,
#                              'market_cap_dominance': 10.0309,
#                              'percent_change_1h': -0.99739495,
#                              'percent_change_24h': -3.28536392,
#                              'percent_change_30d': -20.7335589,
#                              'percent_change_60d': -33.6828236,
#                              'percent_change_7d': -8.78252167,
#                              'percent_change_90d': -18.54325875,
#                              'price': 2599.658880594776,
#                              'tvl': None,
#                              'volume_24h': 18550973938.481617,
#                              'volume_change_24h': -16.0453}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'ethereum',
#            'symbol': 'ETH',
#            'tags': ['pos',
#                     'smart-contracts',
#                     'ethereum-ecosystem',
#                     'coinbase-ventures-portfolio',
#                     'three-arrows-capital-portfolio',
#                     'polychain-capital-portfolio',
#                     'heco-ecosystem',
#                     'binance-labs-portfolio',
#                     'avalanche-ecosystem',
#                     'solana-ecosystem',
#                     'blockchain-capital-portfolio',
#                     'boostvc-portfolio',
#                     'cms-holdings-portfolio',
#                     'dcg-portfolio',
#                     'dragonfly-capital-portfolio',
#                     'electric-capital-portfolio',
#                     'fabric-ventures-portfolio',
#                     'framework-ventures-portfolio',
#                     'hashkey-capital-portfolio',
#                     'kenetic-capital-portfolio',
#                     'huobi-capital-portfolio',
#                     'alameda-research-portfolio',
#                     'a16z-portfolio',
#                     '1confirmation-portfolio',
#                     'winklevoss-capital-portfolio',
#                     'usv-portfolio',
#                     'placeholder-ventures-portfolio',
#                     'pantera-capital-portfolio',
#                     'multicoin-capital-portfolio',
#                     'paradigm-portfolio',
#                     'tezos-ecosystem',
#                     'near-protocol-ecosystem',
#                     'bnb-chain-ecosystem',
#                     'velas-ecosystem',
#                     'ethereum-pow-ecosystem',
#                     'osmosis-ecosystem',
#                     'layer-1',
#                     'ftx-bankruptcy-estate',
#                     'zksync-era-ecosystem',
#                     'viction-ecosystem',
#                     'klaytn-ecosystem',
#                     'sora-ecosystem',
#                     'rsk-rbtc-ecosystem',
#                     'starknet-ecosystem'],
#            'total_supply': 120540713.49245739,
#            'tvl_ratio': None},
#           {'circulating_supply': 141879510828.92145,
#            'cmc_rank': 3,
#            'date_added': '2015-02-25T00:00:00.000Z',
#            'id': 825,
#            'infinite_supply': True,
#            'last_updated': '2025-02-11T19:33:00.000Z',
#            'max_supply': None,
#            'name': 'Tether USDt',
#            'num_market_pairs': 116202,
#            'platform': {'id': 1027,
#                         'name': 'Ethereum',
#                         'slug': 'ethereum',
#                         'symbol': 'ETH',
#                         'token_address': '0xdac17f958d2ee523a2206206994597c13d831ec7'},
#            'quote': {'USD': {'fully_diluted_market_cap': 143560528578.11,
#                              'last_updated': '2025-02-11T19:33:00.000Z',
#                              'market_cap': 141869588826.37732,
#                              'market_cap_dominance': 4.5381,
#                              'percent_change_1h': 0.01019865,
#                              'percent_change_24h': -0.03013484,
#                              'percent_change_30d': 0.03219728,
#                              'percent_change_60d': -0.00524565,
#                              'percent_change_7d': -0.07870579,
#                              'percent_change_90d': -0.10542587,
#                              'price': 0.9999300674037699,
#                              'tvl': None,
#                              'volume_24h': 78409762737.8934,
#                              'volume_change_24h': -12.5929}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'tether',
#            'symbol': 'USDT',
#            'tags': ['stablecoin',
#                     'asset-backed-stablecoin',
#                     'ethereum-ecosystem',
#                     'waves-ecosystem',
#                     'bitcoin-cash-ecosystem',
#                     'heco-ecosystem',
#                     'algorand-ecosystem',
#                     'avalanche-ecosystem',
#                     'solana-ecosystem',
#                     'polygon-ecosystem',
#                     'fantom-ecosystem',
#                     'terra-ecosystem',
#                     'tezos-ecosystem',
#                     'near-protocol-ecosystem',
#                     'arbitrum-ecosystem',
#                     'celo-ecosystem',
#                     'iotex-ecosystem',
#                     'zilliqa-ecosystem',
#                     'harmony-ecosystem',
#                     'moonriver-ecosystem',
#                     'cronos-ecosystem',
#                     'injective-ecosystem',
#                     'bnb-chain-ecosystem',
#                     'oasis-ecosystem',
#                     'moonbeam-ecosystem',
#                     'usd-stablecoin',
#                     'xdc-ecosystem',
#                     'everscale-ecosystem',
#                     'velas-ecosystem',
#                     'doge-chain-ecosystem',
#                     'ethereum-pow-ecosystem',
#                     'aptos-ecosystem',
#                     'sui-ecosystem',
#                     'optimism-ecosystem',
#                     'canto-ecosystem',
#                     'osmosis-ecosystem',
#                     'zksync-era-ecosystem',
#                     'pulsechain-ecosystem',
#                     'sei-ecosystem',
#                     'toncoin-ecosystem',
#                     'fiat-stablecoin',
#                     'viction-ecosystem',
#                     'gnosis-chain-ecosystem',
#                     'klaytn-ecosystem',
#                     'okexchain-ecosystem',
#                     'conflux-ecosystem',
#                     'kcc-ecosystem',
#                     'tron20-ecosystem',
#                     'kardiachain-ecosystem',
#                     'rsk-rbtc-ecosystem',
#                     'telos-ecosystem',
#                     'boba-network-ecosystem',
#                     'fusion-network-ecosystem',
#                     'hoo-smart-chain-ecosystem',
#                     'secret-ecosystem',
#                     'aurora-ecosystem',
#                     'metis-andromeda-ecosystem',
#                     'meter-ecosystem',
#                     'fuse-ecosystem',
#                     'syscoin-ecosystem',
#                     'milkomeda-ecosystem',
#                     'bitgert-ecosystem',
#                     'astar-ecosystem',
#                     'cube-network-ecosystem',
#                     'thundercore-ecosystem',
#                     'redlight-chain-ecosystem',
#                     'core-ecosystem',
#                     'polygon-zkevm-ecosystem',
#                     'eos-evm-ecosystem',
#                     'starknet-ecosystem',
#                     'mantle-ecosystem',
#                     'neon-evm-ecosystem',
#                     'manta-pacific-ecosystem',
#                     'scroll-ecosystem',
#                     'x-layer-ecosystem'],
#            'total_supply': 143570568840.727,
#            'tvl_ratio': None},
#           {'circulating_supply': 57762545657,
#            'cmc_rank': 4,
#            'date_added': '2013-08-04T00:00:00.000Z',
#            'id': 52,
#            'infinite_supply': False,
#            'last_updated': '2025-02-11T19:33:00.000Z',
#            'max_supply': 100000000000,
#            'name': 'XRP',
#            'num_market_pairs': 1526,
#            'platform': None,
#            'quote': {'USD': {'fully_diluted_market_cap': 239016291875.13,
#                              'last_updated': '2025-02-11T19:33:00.000Z',
#                              'market_cap': 138061894722.04224,
#                              'market_cap_dominance': 4.412,
#                              'percent_change_1h': -0.55627121,
#                              'percent_change_24h': -2.01897428,
#                              'percent_change_30d': -6.04085772,
#                              'percent_change_60d': -1.43606804,
#                              'percent_change_7d': -11.20361922,
#                              'percent_change_90d': 246.74720789,
#                              'price': 2.390162918751333,
#                              'tvl': None,
#                              'volume_24h': 4964928494.942722,
#                              'volume_change_24h': -11.8999}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'xrp',
#            'symbol': 'XRP',
#            'tags': ['medium-of-exchange',
#                     'enterprise-solutions',
#                     'xrp-ecosystem',
#                     'arrington-xrp-capital-portfolio',
#                     'galaxy-digital-portfolio',
#                     'a16z-portfolio',
#                     'pantera-capital-portfolio',
#                     'bnb-chain-ecosystem',
#                     'ftx-bankruptcy-estate',
#                     '2017-2018-alt-season',
#                     'klaytn-ecosystem',
#                     'made-in-america'],
#            'total_supply': 99986504676,
#            'tvl_ratio': None},
#           {'circulating_supply': 488072511.6001677,
#            'cmc_rank': 5,
#            'date_added': '2020-04-10T00:00:00.000Z',
#            'id': 5426,
#            'infinite_supply': True,
#            'last_updated': '2025-02-11T19:33:00.000Z',
#            'max_supply': None,
#            'name': 'Solana',
#            'num_market_pairs': 840,
#            'platform': None,
#            'quote': {'USD': {'fully_diluted_market_cap': 116382589423.83,
#                              'last_updated': '2025-02-11T19:33:00.000Z',
#                              'market_cap': 95663604937.1979,
#                              'market_cap_dominance': 3.0614,
#                              'percent_change_1h': -0.48647366,
#                              'percent_change_24h': -3.43806835,
#                              'percent_change_30d': 3.75495584,
#                              'percent_change_60d': -12.14596569,
#                              'percent_change_7d': -9.97053161,
#                              'percent_change_90d': -8.74569815,
#                              'price': 196.00285339479674,
#                              'tvl': None,
#                              'volume_24h': 3833362783.5423703,
#                              'volume_change_24h': -13.7396}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'solana',
#            'symbol': 'SOL',
#            'tags': ['pos',
#                     'platform',
#                     'solana-ecosystem',
#                     'cms-holdings-portfolio',
#                     'kenetic-capital-portfolio',
#                     'alameda-research-portfolio',
#                     'multicoin-capital-portfolio',
#                     'okx-ventures-portfolio',
#                     'layer-1',
#                     'ftx-bankruptcy-estate',
#                     'alleged-sec-securities',
#                     'cmc-crypto-awards-2024',
#                     'made-in-america'],
#            'total_supply': 593780077.2185941,
#            'tvl_ratio': None},
#           {'circulating_supply': 142479449.07,
#            'cmc_rank': 6,
#            'date_added': '2017-07-25T00:00:00.000Z',
#            'id': 1839,
#            'infinite_supply': False,
#            'last_updated': '2025-02-11T19:33:00.000Z',
#            'max_supply': None,
#            'name': 'BNB',
#            'num_market_pairs': 2355,
#            'platform': None,
#            'quote': {'USD': {'fully_diluted_market_cap': 89569472363.77,
#                              'last_updated': '2025-02-11T19:33:00.000Z',
#                              'market_cap': 89569472363.76883,
#                              'market_cap_dominance': 2.8654,
#                              'percent_change_1h': -0.25155623,
#                              'percent_change_24h': 2.31311733,
#                              'percent_change_30d': -9.62292511,
#                              'percent_change_60d': -13.0283703,
#                              'percent_change_7d': 7.10120328,
#                              'percent_change_90d': 1.84935364,
#                              'price': 628.6483626123754,
#                              'tvl': None,
#                              'volume_24h': 2053913675.6774945,
#                              'volume_change_24h': 5.1329}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'bnb',
#            'symbol': 'BNB',
#            'tags': ['marketplace',
#                     'centralized-exchange',
#                     'payments',
#                     'smart-contracts',
#                     'ethereum-ecosystem',
#                     'alameda-research-portfolio',
#                     'multicoin-capital-portfolio',
#                     'bnb-chain-ecosystem',
#                     'layer-1',
#                     'alleged-sec-securities',
#                     'celsius-bankruptcy-estate'],
#            'total_supply': 142479449.07,
#            'tvl_ratio': None},
#           {'circulating_supply': 56328766753.42064,
#            'cmc_rank': 7,
#            'date_added': '2018-10-08T00:00:00.000Z',
#            'id': 3408,
#            'infinite_supply': False,
#            'last_updated': '2025-02-11T19:33:00.000Z',
#            'max_supply': None,
#            'name': 'USDC',
#            'num_market_pairs': 25626,
#            'platform': {'id': 1027,
#                         'name': 'Ethereum',
#                         'slug': 'ethereum',
#                         'symbol': 'ETH',
#                         'token_address': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48'},
#            'quote': {'USD': {'fully_diluted_market_cap': 56329749213.59,
#                              'last_updated': '2025-02-11T19:33:00.000Z',
#                              'market_cap': 56329749213.59478,
#                              'market_cap_dominance': 1.8027,
#                              'percent_change_1h': 0.00950398,
#                              'percent_change_24h': -0.00528447,
#                              'percent_change_30d': -0.0012667,
#                              'percent_change_60d': 0.00064148,
#                              'percent_change_7d': 0.00132056,
#                              'percent_change_90d': 0.02241029,
#                              'price': 1.0000174415353071,
#                              'tvl': None,
#                              'volume_24h': 6975047982.054493,
#                              'volume_change_24h': -9.4237}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'usd-coin',
#            'symbol': 'USDC',
#            'tags': ['medium-of-exchange',
#                     'stablecoin',
#                     'asset-backed-stablecoin',
#                     'ethereum-ecosystem',
#                     'waves-ecosystem',
#                     'bitcoin-cash-ecosystem',
#                     'wanchain-ecosystem',
#                     'coinbase-ventures-portfolio',
#                     'algorand-ecosystem',
#                     'avalanche-ecosystem',
#                     'solana-ecosystem',
#                     'hedera-hashgraph-ecosystem',
#                     'polygon-ecosystem',
#                     'terra-ecosystem',
#                     'near-protocol-ecosystem',
#                     'arbitrum-ecosystem',
#                     'celo-ecosystem',
#                     'iotex-ecosystem',
#                     'harmony-ecosystem',
#                     'moonriver-ecosystem',
#                     'cronos-ecosystem',
#                     'injective-ecosystem',
#                     'bnb-chain-ecosystem',
#                     'oasis-ecosystem',
#                     'moonbeam-ecosystem',
#                     'usd-stablecoin',
#                     'everscale-ecosystem',
#                     'velas-ecosystem',
#                     'doge-chain-ecosystem',
#                     'ethereum-pow-ecosystem',
#                     'aptos-ecosystem',
#                     'sui-ecosystem',
#                     'optimism-ecosystem',
#                     'canto-ecosystem',
#                     'osmosis-ecosystem',
#                     'zksync-era-ecosystem',
#                     'pulsechain-ecosystem',
#                     'base-ecosystem',
#                     'sei-ecosystem',
#                     'multiversx-ecosystem',
#                     'fiat-stablecoin',
#                     'viction-ecosystem',
#                     'gnosis-chain-ecosystem',
#                     'okexchain-ecosystem',
#                     'conflux-ecosystem',
#                     'kcc-ecosystem',
#                     'tron20-ecosystem',
#                     'kardiachain-ecosystem',
#                     'telos-ecosystem',
#                     'ronin-ecosystem',
#                     'boba-network-ecosystem',
#                     'kava-ecosystem',
#                     'secret-ecosystem',
#                     'aurora-ecosystem',
#                     'metis-andromeda-ecosystem',
#                     'meter-ecosystem',
#                     'fuse-ecosystem',
#                     'elastos-ecosystem',
#                     'syscoin-ecosystem',
#                     'milkomeda-ecosystem',
#                     'evmos-ecosystem',
#                     'bitgert-ecosystem',
#                     'astar-ecosystem',
#                     'thundercore-ecosystem',
#                     'tomb-chain-ecosystem',
#                     'wemix-ecosystem',
#                     'sx-network-ecosystem',
#                     'godwoken-ecosystem',
#                     'energi-ecosystem',
#                     'core-ecosystem',
#                     'polygon-zkevm-ecosystem',
#                     'starknet-ecosystem',
#                     'mantle-ecosystem',
#                     'neon-evm-ecosystem',
#                     'scroll-ecosystem',
#                     'shido-network-ecosystem',
#                     'made-in-america'],
#            'total_supply': 56328766753.42064,
#            'tvl_ratio': None},
#           {'circulating_supply': 148004726383.7052,
#            'cmc_rank': 8,
#            'date_added': '2013-12-15T00:00:00.000Z',
#            'id': 74,
#            'infinite_supply': True,
#            'last_updated': '2025-02-11T19:33:00.000Z',
#            'max_supply': None,
#            'name': 'Dogecoin',
#            'num_market_pairs': 1162,
#            'platform': None,
#            'quote': {'USD': {'fully_diluted_market_cap': 37020808275.43,
#                              'last_updated': '2025-02-11T19:33:00.000Z',
#                              'market_cap': 37020808275.431335,
#                              'market_cap_dominance': 1.1842,
#                              'percent_change_1h': -1.19689856,
#                              'percent_change_24h': -1.83209532,
#                              'percent_change_30d': -26.19184479,
#                              'percent_change_60d': -37.74630201,
#                              'percent_change_7d': -8.9778946,
#                              'percent_change_90d': -35.85777387,
#                              'price': 0.2501326084645037,
#                              'tvl': None,
#                              'volume_24h': 1603765790.2894752,
#                              'volume_change_24h': 2.897}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'dogecoin',
#            'symbol': 'DOGE',
#            'tags': ['mineable',
#                     'pow',
#                     'scrypt',
#                     'medium-of-exchange',
#                     'memes',
#                     'payments',
#                     'doggone-doggerel',
#                     'bnb-chain-ecosystem',
#                     'ftx-bankruptcy-estate',
#                     'made-in-america'],
#            'total_supply': 148004726383.7052,
#            'tvl_ratio': None},
#           {'circulating_supply': 35197202831.96437,
#            'cmc_rank': 9,
#            'date_added': '2017-10-01T00:00:00.000Z',
#            'id': 2010,
#            'infinite_supply': False,
#            'last_updated': '2025-02-11T19:32:00.000Z',
#            'max_supply': 45000000000,
#            'name': 'Cardano',
#            'num_market_pairs': 1460,
#            'platform': None,
#            'quote': {'USD': {'fully_diluted_market_cap': 34113985066.98,
#                              'last_updated': '2025-02-11T19:32:00.000Z',
#                              'market_cap': 26682596706.868546,
#                              'market_cap_dominance': 0.8525,
#                              'percent_change_1h': 0.02635933,
#                              'percent_change_24h': 7.58899027,
#                              'percent_change_30d': -22.94363163,
#                              'percent_change_60d': -30.97967261,
#                              'percent_change_7d': -3.03218477,
#                              'percent_change_90d': 32.78502603,
#                              'price': 0.758088557043991,
#                              'tvl': None,
#                              'volume_24h': 1666892235.4917257,
#                              'volume_change_24h': 101.2684}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'cardano',
#            'symbol': 'ADA',
#            'tags': ['dpos',
#                     'pos',
#                     'platform',
#                     'research',
#                     'smart-contracts',
#                     'staking',
#                     'cardano-ecosystem',
#                     'cardano',
#                     'bnb-chain-ecosystem',
#                     'layer-1',
#                     'alleged-sec-securities',
#                     '2017-2018-alt-season',
#                     'made-in-america'],
#            'total_supply': 44995082706.687096,
#            'tvl_ratio': None},
#           {'circulating_supply': 86102814692.3734,
#            'cmc_rank': 10,
#            'date_added': '2017-09-13T00:00:00.000Z',
#            'id': 1958,
#            'infinite_supply': True,
#            'last_updated': '2025-02-11T19:33:00.000Z',
#            'max_supply': None,
#            'name': 'TRON',
#            'num_market_pairs': 1118,
#            'platform': None,
#            'quote': {'USD': {'fully_diluted_market_cap': 20806605925.64,
#                              'last_updated': '2025-02-11T19:33:00.000Z',
#                              'market_cap': 20806602323.559723,
#                              'market_cap_dominance': 0.666,
#                              'percent_change_1h': -0.30226121,
#                              'percent_change_24h': -0.84321728,
#                              'percent_change_30d': 2.38555951,
#                              'percent_change_60d': -16.40979788,
#                              'percent_change_7d': 5.69147453,
#                              'percent_change_90d': 36.61490462,
#                              'price': 0.24164834097348828,
#                              'tvl': None,
#                              'volume_24h': 585282277.4637994,
#                              'volume_change_24h': -14.9693}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'tron',
#            'symbol': 'TRX',
#            'tags': ['media',
#                     'payments',
#                     'ethereum-ecosystem',
#                     'tron-ecosystem',
#                     'bnb-chain-ecosystem',
#                     'layer-1',
#                     'dwf-labs-portfolio',
#                     'alleged-sec-securities',
#                     '2017-2018-alt-season',
#                     'tron20-ecosystem'],
#            'total_supply': 86102829598.65929,
#            'tvl_ratio': None},
#           {'circulating_supply': 638099970.4527867,
#            'cmc_rank': 11,
#            'date_added': '2017-09-20T00:00:00.000Z',
#            'id': 1975,
#            'infinite_supply': False,
#            'last_updated': '2025-02-11T19:33:00.000Z',
#            'max_supply': None,
#            'name': 'Chainlink',
#            'num_market_pairs': 1926,
#            'platform': {'id': 1027,
#                         'name': 'Ethereum',
#                         'slug': 'ethereum',
#                         'symbol': 'ETH',
#                         'token_address': '0x514910771af9ca656af840dff83e8264ecf986ca'},
#            'quote': {'USD': {'fully_diluted_market_cap': 18346851409.91,
#                              'last_updated': '2025-02-11T19:33:00.000Z',
#                              'market_cap': 11707125342.564152,
#                              'market_cap_dominance': 0.3745,
#                              'percent_change_1h': -0.99890298,
#                              'percent_change_24h': -2.90863572,
#                              'percent_change_30d': -8.31295566,
#                              'percent_change_60d': -34.50534554,
#                              'percent_change_7d': -13.37691003,
#                              'percent_change_90d': 35.82987757,
#                              'price': 18.346851409908297,
#                              'tvl': None,
#                              'volume_24h': 451749717.78934735,
#                              'volume_change_24h': -11.7568}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'chainlink',
#            'symbol': 'LINK',
#            'tags': ['platform',
#                     'defi',
#                     'oracles',
#                     'smart-contracts',
#                     'ethereum-ecosystem',
#                     'substrate',
#                     'polkadot',
#                     'heco-ecosystem',
#                     'avalanche-ecosystem',
#                     'solana-ecosystem',
#                     'framework-ventures-portfolio',
#                     'polygon-ecosystem',
#                     'fantom-ecosystem',
#                     'cardano-ecosystem',
#                     'terra-ecosystem',
#                     'web3',
#                     'near-protocol-ecosystem',
#                     'arbitrum-ecosystem',
#                     'cardano',
#                     'injective-ecosystem',
#                     'bnb-chain-ecosystem',
#                     'optimism-ecosystem',
#                     'real-world-assets',
#                     'celsius-bankruptcy-estate',
#                     'gnosis-chain-ecosystem',
#                     'sora-ecosystem',
#                     'hoo-smart-chain-ecosystem',
#                     'milkomeda-ecosystem',
#                     'energi-ecosystem',
#                     'made-in-america'],
#            'total_supply': 1000000000,
#            'tvl_ratio': None},
#           {'circulating_supply': 411894361.531686,
#            'cmc_rank': 12,
#            'date_added': '2020-07-13T00:00:00.000Z',
#            'id': 5805,
#            'infinite_supply': False,
#            'last_updated': '2025-02-11T19:33:00.000Z',
#            'max_supply': 715748719,
#            'name': 'Avalanche',
#            'num_market_pairs': 860,
#            'platform': None,
#            'quote': {'USD': {'fully_diluted_market_cap': 17930706052.14,
#                              'last_updated': '2025-02-11T19:33:00.000Z',
#                              'market_cap': 10318644693.459444,
#                              'market_cap_dominance': 0.3301,
#                              'percent_change_1h': -0.69181458,
#                              'percent_change_24h': -2.31776461,
#                              'percent_change_30d': -32.00084179,
#                              'percent_change_60d': -51.06034829,
#                              'percent_change_7d': -9.90597848,
#                              'percent_change_90d': -24.23586687,
#                              'price': 25.051677461881585,
#                              'tvl': None,
#                              'volume_24h': 341829079.1048452,
#                              'volume_change_24h': -3.6268}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'avalanche',
#            'symbol': 'AVAX',
#            'tags': ['defi',
#                     'smart-contracts',
#                     'three-arrows-capital-portfolio',
#                     'polychain-capital-portfolio',
#                     'avalanche-ecosystem',
#                     'cms-holdings-portfolio',
#                     'dragonfly-capital-portfolio',
#                     'bnb-chain-ecosystem',
#                     'moonbeam-ecosystem',
#                     'real-world-assets',
#                     'layer-1',
#                     'zksync-era-ecosystem',
#                     'klaytn-ecosystem',
#                     'made-in-america'],
#            'total_supply': 450230661.531686,
#            'tvl_ratio': None},
#           {'circulating_supply': 3089707194.508888,
#            'cmc_rank': 13,
#            'date_added': '2022-07-12T08:03:11.000Z',
#            'id': 20947,
#            'infinite_supply': False,
#            'last_updated': '2025-02-11T19:33:00.000Z',
#            'max_supply': 10000000000,
#            'name': 'Sui',
#            'num_market_pairs': 553,
#            'platform': None,
#            'quote': {'USD': {'fully_diluted_market_cap': 32693200356.83,
#                              'last_updated': '2025-02-11T19:33:00.000Z',
#                              'market_cap': 10101241635.402086,
#                              'market_cap_dominance': 0.3231,
#                              'percent_change_1h': -2.24049157,
#                              'percent_change_24h': -0.24794017,
#                              'percent_change_30d': -31.29602019,
#                              'percent_change_60d': -30.77471623,
#                              'percent_change_7d': -15.38609654,
#                              'percent_change_90d': 0.85737304,
#                              'price': 3.2693200356830863,
#                              'tvl': None,
#                              'volume_24h': 1349283301.011952,
#                              'volume_change_24h': -14.2581}},
#            'self_reported_circulating_supply': 3089707194.508888,
#            'self_reported_market_cap': 10101241635.402086,
#            'slug': 'sui',
#            'symbol': 'SUI',
#            'tags': ['binance-launchpool',
#                     'coinbase-ventures-portfolio',
#                     'binance-labs-portfolio',
#                     'electric-capital-portfolio',
#                     'a16z-portfolio',
#                     'sui-ecosystem',
#                     'layer-1',
#                     'move-vm',
#                     'cmc-crypto-yearbook-2024-2025',
#                     'made-in-america'],
#            'total_supply': 10000000000,
#            'tvl_ratio': None},
#           {'circulating_supply': 30592512784.497433,
#            'cmc_rank': 14,
#            'date_added': '2014-08-05T00:00:00.000Z',
#            'id': 512,
#            'infinite_supply': False,
#            'last_updated': '2025-02-11T19:33:00.000Z',
#            'max_supply': 50001806812,
#            'name': 'Stellar',
#            'num_market_pairs': 670,
#            'platform': None,
#            'quote': {'USD': {'fully_diluted_market_cap': 15892453852.88,
#                              'last_updated': '2025-02-11T19:33:00.000Z',
#                              'market_cap': 9723450584.48118,
#                              'market_cap_dominance': 0.3112,
#                              'percent_change_1h': -0.47092612,
#                              'percent_change_24h': 0.76842237,
#                              'percent_change_30d': -25.73007626,
#                              'percent_change_60d': -26.46056035,
#                              'percent_change_7d': -12.28121281,
#                              'percent_change_90d': 157.454075,
#                              'price': 0.317837591602102,
#                              'tvl': None,
#                              'volume_24h': 389740569.7099803,
#                              'volume_change_24h': 11.0505}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'stellar',
#            'symbol': 'XLM',
#            'tags': ['medium-of-exchange',
#                     'enterprise-solutions',
#                     'decentralized-exchange-dex-token',
#                     'smart-contracts',
#                     'hashkey-capital-portfolio',
#                     '2017-2018-alt-season',
#                     'made-in-america'],
#            'total_supply': 50001786894.45019,
#            'tvl_ratio': None},
#           {'circulating_supply': 2494025283.3153677,
#            'cmc_rank': 15,
#            'date_added': '2021-08-26T13:40:22.000Z',
#            'id': 11419,
#            'infinite_supply': True,
#            'last_updated': '2025-02-11T19:33:00.000Z',
#            'max_supply': None,
#            'name': 'Toncoin',
#            'num_market_pairs': 673,
#            'platform': None,
#            'quote': {'USD': {'fully_diluted_market_cap': 18992908203.32,
#                              'last_updated': '2025-02-11T19:33:00.000Z',
#                              'market_cap': 9247990480.874035,
#                              'market_cap_dominance': 0.296,
#                              'percent_change_1h': -0.98913884,
#                              'percent_change_24h': -3.44038093,
#                              'percent_change_30d': -30.89114948,
#                              'percent_change_60d': -40.5315858,
#                              'percent_change_7d': -6.44252519,
#                              'percent_change_90d': -28.94357788,
#                              'price': 3.7080580308233517,
#                              'tvl': None,
#                              'volume_24h': 123209762.40693091,
#                              'volume_change_24h': -4.7019}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'toncoin',
#            'symbol': 'TON',
#            'tags': ['pos',
#                     'ethereum-ecosystem',
#                     'bnb-chain-ecosystem',
#                     'layer-1',
#                     'ftx-bankruptcy-estate',
#                     'dwf-labs-portfolio',
#                     'toncoin-ecosystem',
#                     'cmc-crypto-yearbook-2024-2025'],
#            'total_supply': 5122063367.250687,
#            'tvl_ratio': None},
#           {'circulating_supply': 589253900860076.2,
#            'cmc_rank': 16,
#            'date_added': '2020-08-01T00:00:00.000Z',
#            'id': 5994,
#            'infinite_supply': False,
#            'last_updated': '2025-02-11T19:33:00.000Z',
#            'max_supply': None,
#            'name': 'Shiba Inu',
#            'num_market_pairs': 932,
#            'platform': {'id': 1027,
#                         'name': 'Ethereum',
#                         'slug': 'ethereum',
#                         'symbol': 'ETH',
#                         'token_address': '0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce'},
#            'quote': {'USD': {'fully_diluted_market_cap': 9167731930.99,
#                              'last_updated': '2025-02-11T19:33:00.000Z',
#                              'market_cap': 9163791797.949762,
#                              'market_cap_dominance': 0.2932,
#                              'percent_change_1h': -0.66427975,
#                              'percent_change_24h': -2.30440417,
#                              'percent_change_30d': -28.49208994,
#                              'percent_change_60d': -44.64460298,
#                              'percent_change_7d': -4.85608705,
#                              'percent_change_90d': -39.05856217,
#                              'price': 1.5551516561153472e-05,
#                              'tvl': None,
#                              'volume_24h': 274008574.41778135,
#                              'volume_change_24h': 10.9367}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'shiba-inu',
#            'symbol': 'SHIB',
#            'tags': ['memes',
#                     'ethereum-ecosystem',
#                     'doggone-doggerel',
#                     'base-ecosystem'],
#            'total_supply': 589507260911478.4,
#            'tvl_ratio': None},
#           {'circulating_supply': 924143188.9,
#            'cmc_rank': 17,
#            'date_added': '2019-05-21T00:00:00.000Z',
#            'id': 3957,
#            'infinite_supply': False,
#            'last_updated': '2025-02-11T19:33:00.000Z',
#            'max_supply': None,
#            'name': 'UNUS SED LEO',
#            'num_market_pairs': 57,
#            'platform': {'id': 1027,
#                         'name': 'Ethereum',
#                         'slug': 'ethereum',
#                         'symbol': 'ETH',
#                         'token_address': '0x2af5d2ad76741191d15dfe7bf6ac92d4bd912ca3'},
#            'quote': {'USD': {'fully_diluted_market_cap': 9634420489.84,
#                              'last_updated': '2025-02-11T19:33:00.000Z',
#                              'market_cap': 9036974297.65397,
#                              'market_cap_dominance': 0.2891,
#                              'percent_change_1h': -0.11883375,
#                              'percent_change_24h': -0.75439212,
#                              'percent_change_30d': 5.30736907,
#                              'percent_change_60d': 3.64267534,
#                              'percent_change_7d': -0.31349384,
#                              'percent_change_90d': 31.12067287,
#                              'price': 9.77875983527034,
#                              'tvl': None,
#                              'volume_24h': 723051.17819183,
#                              'volume_change_24h': 32.6619}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'unus-sed-leo',
#            'symbol': 'LEO',
#            'tags': ['marketplace',
#                     'centralized-exchange',
#                     'discount-token',
#                     'payments',
#                     'ethereum-ecosystem',
#                     'kenetic-capital-portfolio',
#                     'alameda-research-portfolio'],
#            'total_supply': 985239504,
#            'tvl_ratio': None},
#           {'circulating_supply': 75521943.3040892,
#            'cmc_rank': 18,
#            'date_added': '2013-04-28T00:00:00.000Z',
#            'id': 2,
#            'infinite_supply': False,
#            'last_updated': '2025-02-11T19:33:00.000Z',
#            'max_supply': 84000000,
#            'name': 'Litecoin',
#            'num_market_pairs': 1314,
#            'platform': None,
#            'quote': {'USD': {'fully_diluted_market_cap': 10054631776.45,
#                              'last_updated': '2025-02-11T19:33:00.000Z',
#                              'market_cap': 9039825368.623987,
#                              'market_cap_dominance': 0.2892,
#                              'percent_change_1h': -1.07912687,
#                              'percent_change_24h': 0.55329652,
#                              'percent_change_30d': 15.67520848,
#                              'percent_change_60d': -0.16045072,
#                              'percent_change_7d': 13.00134165,
#                              'percent_change_90d': 59.38349196,
#                              'price': 119.6979973386691,
#                              'tvl': None,
#                              'volume_24h': 1933043387.505709,
#                              'volume_change_24h': 29.9165}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'litecoin',
#            'symbol': 'LTC',
#            'tags': ['mineable',
#                     'pow',
#                     'scrypt',
#                     'medium-of-exchange',
#                     'heco-ecosystem',
#                     'bnb-chain-ecosystem',
#                     '2017-2018-alt-season',
#                     'hoo-smart-chain-ecosystem',
#                     'made-in-america'],
#            'total_supply': 84000000,
#            'tvl_ratio': None},
#           {'circulating_supply': 38267523197.971344,
#            'cmc_rank': 19,
#            'date_added': '2019-09-17T00:00:00.000Z',
#            'id': 4642,
#            'infinite_supply': False,
#            'last_updated': '2025-02-11T19:32:00.000Z',
#            'max_supply': 50000000000,
#            'name': 'Hedera',
#            'num_market_pairs': 316,
#            'platform': None,
#            'quote': {'USD': {'fully_diluted_market_cap': 11381902572.29,
#                              'last_updated': '2025-02-11T19:32:00.000Z',
#                              'market_cap': 8711144414.444979,
#                              'market_cap_dominance': 0.2783,
#                              'percent_change_1h': -1.03903414,
#                              'percent_change_24h': -3.75683793,
#                              'percent_change_30d': -19.41592555,
#                              'percent_change_60d': -26.58844193,
#                              'percent_change_7d': -14.94312,
#                              'percent_change_90d': 288.6973676,
#                              'price': 0.22763805144584792,
#                              'tvl': None,
#                              'volume_24h': 308400306.99461246,
#                              'volume_change_24h': 2.4389}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'hedera',
#            'symbol': 'HBAR',
#            'tags': ['dag',
#                     'marketplace',
#                     'enterprise-solutions',
#                     'defi',
#                     'payments',
#                     'dcg-portfolio',
#                     'hedera-hashgraph-ecosystem',
#                     'real-world-assets',
#                     'layer-1',
#                     'made-in-america'],
#            'total_supply': 50000000000,
#            'tvl_ratio': None},
#           {'circulating_supply': 333928180,
#            'cmc_rank': 20,
#            'date_added': '2024-07-15T10:14:50.000Z',
#            'id': 32196,
#            'infinite_supply': False,
#            'last_updated': '2025-02-11T19:33:00.000Z',
#            'max_supply': 1000000000,
#            'name': 'Hyperliquid',
#            'num_market_pairs': 51,
#            'platform': {'id': 32196,
#                         'name': 'Hyperliquid',
#                         'slug': 'hyperliquid',
#                         'symbol': 'HYPE',
#                         'token_address': '0x0d01dc56dcaaca66ad901c959b4011ec'},
#            'quote': {'USD': {'fully_diluted_market_cap': 22965514478.9,
#                              'last_updated': '2025-02-11T19:33:00.000Z',
#                              'market_cap': 7668832452.702704,
#                              'market_cap_dominance': 0.2453,
#                              'percent_change_1h': -1.34927529,
#                              'percent_change_24h': -3.79751998,
#                              'percent_change_30d': 6.22425436,
#                              'percent_change_60d': 18.76902346,
#                              'percent_change_7d': -13.3852946,
#                              'percent_change_90d': 617.61032748,
#                              'price': 22.965514478899937,
#                              'tvl': None,
#                              'volume_24h': 126602359.38536172,
#                              'volume_change_24h': 10.6495}},
#            'self_reported_circulating_supply': 333931719,
#            'self_reported_market_cap': 7668913727.658445,
#            'slug': 'hyperliquid',
#            'symbol': 'HYPE',
#            'tags': ['decentralized-exchange-dex-token',
#                     'derivatives',
#                     'layer-1',
#                     'hyperliquid-ecosystem'],
#            'total_supply': 999993930,
#            'tvl_ratio': None},
#           {'circulating_supply': 1200000000,
#            'cmc_rank': 21,
#            'date_added': '2021-07-29T00:00:00.000Z',
#            'id': 11092,
#            'infinite_supply': False,
#            'last_updated': '2025-02-11T19:33:00.000Z',
#            'max_supply': None,
#            'name': 'Bitget Token',
#            'num_market_pairs': 29,
#            'platform': {'id': 1027,
#                         'name': 'Ethereum',
# ...
#                              'percent_change_24h': -6.941707,
#                              'percent_change_30d': 701.27317037,
#                              'percent_change_60d': 769.88697422,
#                              'percent_change_7d': -32.42055086,
#                              'percent_change_90d': 1357.38119809,
#                              'price': 0.021439440704135528,
#                              'tvl': None,
#                              'volume_24h': 147187061.21427462,
#                              'volume_change_24h': 31.6761}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'onyxcoin',
#            'symbol': 'XCN',
#            'tags': ['ethereum-ecosystem',
#                     'bnb-chain-ecosystem',
#                     'base-ecosystem',
#                     'made-in-america'],
#            'total_supply': 48402437326,
#            'tvl_ratio': None},
#           {'circulating_supply': 1282163861,
#            'cmc_rank': 94,
#            'date_added': '2020-08-14T00:00:00.000Z',
#            'id': 6538,
#            'infinite_supply': False,
#            'last_updated': '2025-02-11T19:33:00.000Z',
#            'max_supply': None,
#            'name': 'Curve DAO Token',
#            'num_market_pairs': 810,
#            'platform': {'id': 1027,
#                         'name': 'Ethereum',
#                         'slug': 'ethereum',
#                         'symbol': 'ETH',
#                         'token_address': '0xD533a949740bb3306d119CC777fa900bA034cd52'},
#            'quote': {'USD': {'fully_diluted_market_cap': 1196302735.53,
#                              'last_updated': '2025-02-11T19:33:00.000Z',
#                              'market_cap': 689267313.2310758,
#                              'market_cap_dominance': 0.0221,
#                              'percent_change_1h': -1.32973304,
#                              'percent_change_24h': -1.47532897,
#                              'percent_change_30d': -35.3817284,
#                              'percent_change_60d': -52.8227655,
#                              'percent_change_7d': -2.70495445,
#                              'percent_change_90d': 73.01374142,
#                              'price': 0.5375812984570432,
#                              'tvl': None,
#                              'volume_24h': 168165622.29459974,
#                              'volume_change_24h': -8.1284}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'curve-dao-token',
#            'symbol': 'CRV',
#            'tags': ['decentralized-exchange-dex-token',
#                     'defi',
#                     'dao',
#                     'ethereum-ecosystem',
#                     'yield-farming',
#                     'amm',
#                     'governance',
#                     'framework-ventures-portfolio',
#                     'alameda-research-portfolio',
#                     'polygon-ecosystem',
#                     'fantom-ecosystem',
#                     'arbitrum-ecosystem',
#                     'optimism-ecosystem',
#                     'dwf-labs-portfolio',
#                     'base-ecosystem',
#                     'gnosis-chain-ecosystem'],
#            'total_supply': 2225342918.2973266,
#            'tvl_ratio': None},
#           {'circulating_supply': 483313291.359223,
#            'cmc_rank': 95,
#            'date_added': '2025-01-19T23:21:51.000Z',
#            'id': 35347,
#            'infinite_supply': False,
#            'last_updated': '2025-02-11T19:33:00.000Z',
#            'max_supply': 1000000000,
#            'name': 'Official Melania Meme',
#            'num_market_pairs': 246,
#            'platform': None,
#            'quote': {'USD': {'fully_diluted_market_cap': 1407060546.83,
#                              'last_updated': '2025-02-11T19:33:00.000Z',
#                              'market_cap': 680051064.0290061,
#                              'market_cap_dominance': 0.0218,
#                              'percent_change_1h': -0.18729304,
#                              'percent_change_24h': -2.77558521,
#                              'percent_change_30d': -80.79898575,
#                              'percent_change_60d': -80.79898575,
#                              'percent_change_7d': -19.57999913,
#                              'percent_change_90d': -80.79898575,
#                              'price': 1.4070605468277049,
#                              'tvl': None,
#                              'volume_24h': 47512768.87855246,
#                              'volume_change_24h': -9.1814}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'melania-meme',
#            'symbol': 'MELANIA',
#            'tags': ['memes',
#                     'solana-ecosystem',
#                     'celebrity-memes',
#                     'made-in-america'],
#            'total_supply': 999999388.275755,
#            'tvl_ratio': None},
#           {'circulating_supply': 158535269.44849598,
#            'cmc_rank': 96,
#            'date_added': '2020-08-31T00:00:00.000Z',
#            'id': 6783,
#            'infinite_supply': False,
#            'last_updated': '2025-02-11T19:33:00.000Z',
#            'max_supply': None,
#            'name': 'Axie Infinity',
#            'num_market_pairs': 506,
#            'platform': {'id': 1027,
#                         'name': 'Ethereum',
#                         'slug': 'ethereum',
#                         'symbol': 'ETH',
#                         'token_address': '0xbb0e17ef65f82ab018d8edd776e8dd940327b28b'},
#            'quote': {'USD': {'fully_diluted_market_cap': 1134615735.06,
#                              'last_updated': '2025-02-11T19:33:00.000Z',
#                              'market_cap': 666209671.3990633,
#                              'market_cap_dominance': 0.0213,
#                              'percent_change_1h': -1.15989001,
#                              'percent_change_24h': -3.04549726,
#                              'percent_change_30d': -32.08117126,
#                              'percent_change_60d': -46.25160525,
#                              'percent_change_7d': -1.90505611,
#                              'percent_change_90d': -21.15966183,
#                              'price': 4.202280500210697,
#                              'tvl': None,
#                              'volume_24h': 42102319.46529619,
#                              'volume_change_24h': 24.1988}},
#            'self_reported_circulating_supply': 158535282.48648918,
#            'self_reported_market_cap': 666209726.1883678,
#            'slug': 'axie-infinity',
#            'symbol': 'AXS',
#            'tags': ['collectibles-nfts',
#                     'gaming',
#                     'ethereum-ecosystem',
#                     'binance-launchpad',
#                     'solana-ecosystem',
#                     'metaverse',
#                     'defiance-capital-portfolio',
#                     'play-to-earn',
#                     'animoca-brands-portfolio',
#                     'harmony-ecosystem',
#                     'bnb-chain-ecosystem',
#                     'alleged-sec-securities',
#                     'ronin-ecosystem'],
#            'total_supply': 270000000,
#            'tvl_ratio': None},
#           {'circulating_supply': 177394590.46004692,
#            'cmc_rank': 97,
#            'date_added': '2020-06-05T00:00:00.000Z',
#            'id': 5665,
#            'infinite_supply': False,
#            'last_updated': '2025-02-11T19:32:00.000Z',
#            'max_supply': 223000000,
#            'name': 'Helium',
#            'num_market_pairs': 179,
#            'platform': None,
#            'quote': {'USD': {'fully_diluted_market_cap': 831079235.29,
#                              'last_updated': '2025-02-11T19:32:00.000Z',
#                              'market_cap': 661116415.1759355,
#                              'market_cap_dominance': 0.0211,
#                              'percent_change_1h': -0.23551275,
#                              'percent_change_24h': 6.59543889,
#                              'percent_change_30d': -28.49147551,
#                              'percent_change_60d': -54.37794925,
#                              'percent_change_7d': 5.05148042,
#                              'percent_change_90d': -37.17341801,
#                              'price': 3.7268127143078424,
#                              'tvl': None,
#                              'volume_24h': 13534850.69660985,
#                              'volume_change_24h': 109.6748}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'helium',
#            'symbol': 'HNT',
#            'tags': ['mineable',
#                     'enterprise-solutions',
#                     'distributed-computing',
#                     'iot',
#                     'solana-ecosystem',
#                     'usv-portfolio',
#                     'multicoin-capital-portfolio',
#                     'web3',
#                     'depin',
#                     'made-in-america'],
#            'total_supply': 177394590.46004692,
#            'tvl_ratio': None},
#           {'circulating_supply': 930993090.07,
#            'cmc_rank': 98,
#            'date_added': '2023-08-17T10:00:00.000Z',
#            'id': 28081,
#            'infinite_supply': False,
#            'last_updated': '2025-02-11T19:33:00.000Z',
#            'max_supply': 1000000000,
#            'name': 'SPX6900',
#            'num_market_pairs': 327,
#            'platform': {'id': 1027,
#                         'name': 'Ethereum',
#                         'slug': 'ethereum',
#                         'symbol': 'ETH',
#                         'token_address': '0xe0f63a424a4439cbe457d80e4f4b51ad25b2c56c'},
#            'quote': {'USD': {'fully_diluted_market_cap': 697773675.9,
#                              'last_updated': '2025-02-11T19:33:00.000Z',
#                              'market_cap': 649622470.6911851,
#                              'market_cap_dominance': 0.0208,
#                              'percent_change_1h': -0.89296604,
#                              'percent_change_24h': 2.82673863,
#                              'percent_change_30d': -34.78968728,
#                              'percent_change_60d': 2.96568302,
#                              'percent_change_7d': -19.85275435,
#                              'percent_change_90d': 18.542358,
#                              'price': 0.6977736758952109,
#                              'tvl': None,
#                              'volume_24h': 34602432.34264297,
#                              'volume_change_24h': -10.753}},
#            'self_reported_circulating_supply': 930993090.07,
#            'self_reported_market_cap': 649622470.6911851,
#            'slug': 'spx6900',
#            'symbol': 'SPX',
#            'tags': ['memes',
#                     'ethereum-ecosystem',
#                     'solana-ecosystem',
#                     'base-ecosystem'],
#            'total_supply': 930993090.07,
#            'tvl_ratio': None},
#           {'circulating_supply': 328895103.813207,
#            'cmc_rank': 99,
#            'date_added': '2019-07-31T00:00:00.000Z',
#            'id': 4195,
#            'infinite_supply': False,
#            'last_updated': '2025-02-11T19:33:00.000Z',
#            'max_supply': None,
#            'name': 'FTX Token',
#            'num_market_pairs': 245,
#            'platform': {'id': 1027,
#                         'name': 'Ethereum',
#                         'slug': 'ethereum',
#                         'symbol': 'ETH',
#                         'token_address': '0x50d1c9771902476076ecfc8b2a83ad6b9355a4c9'},
#            'quote': {'USD': {'fully_diluted_market_cap': 647423653.72,
#                              'last_updated': '2025-02-11T19:33:00.000Z',
#                              'market_cap': 647423653.7152758,
#                              'market_cap_dominance': 0.0207,
#                              'percent_change_1h': -1.06861484,
#                              'percent_change_24h': -0.38977069,
#                              'percent_change_30d': -28.01447817,
#                              'percent_change_60d': -31.0186213,
#                              'percent_change_7d': 0.3002309,
#                              'percent_change_90d': 8.58027811,
#                              'price': 1.9684806681797677,
#                              'tvl': None,
#                              'volume_24h': 29021419.42014608,
#                              'volume_change_24h': 21.3747}},
#            'self_reported_circulating_supply': None,
#            'self_reported_market_cap': None,
#            'slug': 'ftx-token',
#            'symbol': 'FTT',
#            'tags': ['marketplace',
#                     'centralized-exchange',
#                     'derivatives',
#                     'ethereum-ecosystem',
#                     'solana-ecosystem',
#                     'cms-holdings-portfolio',
#                     'kenetic-capital-portfolio',
#                     'alameda-research-portfolio',
#                     'pantera-capital-portfolio',
#                     'exnetwork-capital-portfolio',
#                     'bnb-chain-ecosystem',
#                     'ftx-bankruptcy-estate',
#                     'alleged-sec-securities',
#                     'celsius-bankruptcy-estate'],
#            'total_supply': 328895103.813207,
#            'tvl_ratio': None},
#           {'circulating_supply': 27856628.91822108,
#            'cmc_rank': 100,
#            'date_added': '2020-09-04T00:00:00.000Z',
#            'id': 6892,
#            'infinite_supply': False,
#            'last_updated': '2025-02-11T19:33:00.000Z',
#            'max_supply': 31415926,
#            'name': 'MultiversX',
#            'num_market_pairs': 282,
#            'platform': None,
#            'quote': {'USD': {'fully_diluted_market_cap': 707352492.57,
#                              'last_updated': '2025-02-11T19:33:00.000Z',
#                              'market_cap': 627212322.1825727,
#                              'market_cap_dominance': 0.0201,
#                              'percent_change_1h': -1.37608229,
#                              'percent_change_24h': -0.07873481,
#                              'percent_change_30d': -32.17611662,
#                              'percent_change_60d': -53.03597824,
#                              'percent_change_7d': -4.57727695,
#                              'percent_change_90d': -23.87798259,
#                              'price': 22.515729524339964,
#                              'tvl': None,
#                              'volume_24h': 23483343.08975007,
#                              'volume_change_24h': -20.7436}},
#            'self_reported_circulating_supply': 27918566,
#            'self_reported_market_cap': 628606880.7634339,
#            'slug': 'multiversx-egld',
#            'symbol': 'EGLD',
#            'tags': ['pos',
#                     'enterprise-solutions',
#                     'distributed-computing',
#                     'loyalty',
#                     'defi',
#                     'gaming',
#                     'identity',
#                     'payments',
#                     'scaling',
#                     'smart-contracts',
#                     'software',
#                     'binance-launchpad',
#                     'binance-labs-portfolio',
#                     'metaverse',
#                     'electric-capital-portfolio',
#                     'exnetwork-capital-portfolio',
#                     'mobile-payment',
#                     'web3',
#                     'elrond-ecosystem',
#                     'injective-ecosystem',
#                     'bnb-chain-ecosystem',
#                     'layer-1',
#                     'dwf-labs-portfolio',
#                     'multiversx-ecosystem',
#                     'depin'],
#            'total_supply': 27918566,
#            'tvl_ratio': None}],
#  'status': {'credit_count': 1,
#             'elapsed': 16,
#             'error_code': 0,
#             'error_message': None,
#             'notice': None,
#             'timestamp': '2025-02-11T19:34:07.712Z',
#             'total_count': 10855}}

# %% [markdown]
# ### List and count fetched crypto 'symbols'

# %%
listings_symbols: set[str] = {quote.get("symbol") for quote in data.get("data", {})}

pprint(listings_symbols)
pprint(f"{len(listings_symbols)=}")
# Out:
# {'AAVE',
#  'ADA',
#  'ALGO',
#  'APT',
#  'ARB',
#  'ATOM',
#  'AVAX',
#  'AXS',
#  'BCH',
#  'BGB',
#  'BNB',
#  'BONK',
#  'BSV',
#  'BTC',
#  'BTT',
#  'CRO',
#  'CRV',
#  'DAI',
#  'DEXE',
#  'DOGE',
#  'DOT',
#  'EGLD',
#  'ENA',
#  'ENS',
#  'EOS',
#  'ETC',
#  'ETH',
#  'FDUSD',
#  'FET',
#  'FIL',
#  'FLOKI',
#  'FLOW',
#  'FLR',
#  'FTT',
#  'GALA',
#  'GRT',
#  'GT',
#  'HBAR',
#  'HNT',
#  'HYPE',
#  'ICP',
#  'IMX',
#  'INJ',
#  'IOTA',
#  'JASMY',
#  'JTO',
#  'JUP',
#  'KAIA',
#  'KAS',
#  'KCS',
#  'LDO',
#  'LEO',
#  'LINK',
#  'LTC',
#  'MELANIA',
#  'MKR',
#  'MNT',
#  'MOVE',
#  'NEAR',
#  'NEO',
#  'NEXO',
#  'OKB',
#  'OM',
#  'ONDO',
#  'OP',
#  'PEPE',
#  'POL',
#  'PYTH',
#  'QNT',
#  'RAY',
#  'RENDER',
#  'RON',
#  'S',
#  'SAND',
#  'SEI',
#  'SHIB',
#  'SOL',
#  'SPX',
#  'STX',
#  'SUI',
#  'TAO',
#  'THETA',
#  'TIA',
#  'TON',
#  'TRUMP',
#  'TRX',
#  'UNI',
#  'USDC',
#  'USDT',
#  'USDe',
#  'VET',
#  'VIRTUAL',
#  'WLD',
#  'XAUt',
#  'XCN',
#  'XDC',
#  'XLM',
#  'XMR',
#  'XRP',
#  'XTZ'}
# 'len(listings_symbols)=100'

# %% [markdown]
# ### Emulate v2 api output using a constant

# %%
COINS = "BTC,ETH"

data = response_api.json()

listings_symbols = {quote.get("symbol").upper() for quote in data.get("data", {})}

coins_select = {s.strip().upper() for s in COINS.split(",")}

if not coins_select <= listings_symbols:
    raise KeyError(f"Symbol not found: {coins_select - listings_symbols}")

quotes_select = {
    q.get("symbol"): [q] for q in data.get("data", {}) if q.get("symbol") in coins_select
}

pprint(quotes_select)
# Out:
# {'BTC': [{'circulating_supply': 19822912,
#           'cmc_rank': 1,
#           'date_added': '2010-07-13T00:00:00.000Z',
#           'id': 1,
#           'infinite_supply': False,
#           'last_updated': '2025-02-11T19:32:00.000Z',
#           'max_supply': 21000000,
#           'name': 'Bitcoin',
#           'num_market_pairs': 11931,
#           'platform': None,
#           'quote': {'USD': {'fully_diluted_market_cap': 1997722769053.91,
#                             'last_updated': '2025-02-11T19:32:00.000Z',
#                             'market_cap': 1885746792921.5217,
#                             'market_cap_dominance': 60.3266,
#                             'percent_change_1h': -0.64581622,
#                             'percent_change_24h': -2.5375842,
#                             'percent_change_30d': 0.44837373,
#                             'percent_change_60d': -6.14327796,
#                             'percent_change_7d': -5.36679904,
#                             'percent_change_90d': 4.7418409,
#                             'price': 95129.65566923375,
#                             'tvl': None,
#                             'volume_24h': 33047141317.35391,
#                             'volume_change_24h': -25.2786}},
#           'self_reported_circulating_supply': None,
#           'self_reported_market_cap': None,
#           'slug': 'bitcoin',
#           'symbol': 'BTC',
#           'tags': ['mineable',
#                    'pow',
#                    'sha-256',
#                    'store-of-value',
#                    'state-channel',
#                    'coinbase-ventures-portfolio',
#                    'three-arrows-capital-portfolio',
#                    'polychain-capital-portfolio',
#                    'binance-labs-portfolio',
#                    'blockchain-capital-portfolio',
#                    'boostvc-portfolio',
#                    'cms-holdings-portfolio',
#                    'dcg-portfolio',
#                    'dragonfly-capital-portfolio',
#                    'electric-capital-portfolio',
#                    'fabric-ventures-portfolio',
#                    'framework-ventures-portfolio',
#                    'galaxy-digital-portfolio',
#                    'huobi-capital-portfolio',
#                    'alameda-research-portfolio',
#                    'a16z-portfolio',
#                    '1confirmation-portfolio',
#                    'winklevoss-capital-portfolio',
#                    'usv-portfolio',
#                    'placeholder-ventures-portfolio',
#                    'pantera-capital-portfolio',
#                    'multicoin-capital-portfolio',
#                    'paradigm-portfolio',
#                    'bitcoin-ecosystem',
#                    'ftx-bankruptcy-estate',
#                    '2017-2018-alt-season'],
#           'total_supply': 19822912,
#           'tvl_ratio': None}],
#  'ETH': [{'circulating_supply': 120540713.49245739,
#           'cmc_rank': 2,
#           'date_added': '2015-08-07T00:00:00.000Z',
#           'id': 1027,
#           'infinite_supply': True,
#           'last_updated': '2025-02-11T19:33:00.000Z',
#           'max_supply': None,
#           'name': 'Ethereum',
#           'num_market_pairs': 9923,
#           'platform': None,
#           'quote': {'USD': {'fully_diluted_market_cap': 313364736303.9,
#                             'last_updated': '2025-02-11T19:33:00.000Z',
#                             'market_cap': 313364736303.8974,
#                             'market_cap_dominance': 10.0309,
#                             'percent_change_1h': -0.99739495,
#                             'percent_change_24h': -3.28536392,
#                             'percent_change_30d': -20.7335589,
#                             'percent_change_60d': -33.6828236,
#                             'percent_change_7d': -8.78252167,
#                             'percent_change_90d': -18.54325875,
#                             'price': 2599.658880594776,
#                             'tvl': None,
#                             'volume_24h': 18550973938.481617,
#                             'volume_change_24h': -16.0453}},
#           'self_reported_circulating_supply': None,
#           'self_reported_market_cap': None,
#           'slug': 'ethereum',
#           'symbol': 'ETH',
#           'tags': ['pos',
#                    'smart-contracts',
#                    'ethereum-ecosystem',
#                    'coinbase-ventures-portfolio',
#                    'three-arrows-capital-portfolio',
#                    'polychain-capital-portfolio',
#                    'heco-ecosystem',
#                    'binance-labs-portfolio',
#                    'avalanche-ecosystem',
#                    'solana-ecosystem',
#                    'blockchain-capital-portfolio',
#                    'boostvc-portfolio',
#                    'cms-holdings-portfolio',
#                    'dcg-portfolio',
#                    'dragonfly-capital-portfolio',
#                    'electric-capital-portfolio',
#                    'fabric-ventures-portfolio',
#                    'framework-ventures-portfolio',
#                    'hashkey-capital-portfolio',
#                    'kenetic-capital-portfolio',
#                    'huobi-capital-portfolio',
#                    'alameda-research-portfolio',
#                    'a16z-portfolio',
#                    '1confirmation-portfolio',
#                    'winklevoss-capital-portfolio',
#                    'usv-portfolio',
#                    'placeholder-ventures-portfolio',
#                    'pantera-capital-portfolio',
#                    'multicoin-capital-portfolio',
#                    'paradigm-portfolio',
#                    'tezos-ecosystem',
#                    'near-protocol-ecosystem',
#                    'bnb-chain-ecosystem',
#                    'velas-ecosystem',
#                    'ethereum-pow-ecosystem',
#                    'osmosis-ecosystem',
#                    'layer-1',
#                    'ftx-bankruptcy-estate',
#                    'zksync-era-ecosystem',
#                    'viction-ecosystem',
#                    'klaytn-ecosystem',
#                    'sora-ecosystem',
#                    'rsk-rbtc-ecosystem',
#                    'starknet-ecosystem'],
#           'total_supply': 120540713.49245739,
#           'tvl_ratio': None}]}

# %% [markdown]
# ### Using dataclasses
# Dataclass as a single "point of truth" to refer to in other scripts.
#
# Put in models.py

# %%
from dataclasses import dataclass


@dataclass
class CoinData:
    kafka_key: str
    kafka_value: dict


COINS = "BTC,ETH"

data = response_api.json()

listings_symbols = {quote.get("symbol").upper() for quote in data.get("data", {})}

coins_select = {s.strip().upper() for s in COINS.split(",")}

if not coins_select <= listings_symbols:
    raise KeyError(f"Symbol not found: {coins_select - listings_symbols}")

coin_data = [
    CoinData(
        kafka_key=q.get("symbol"),
        kafka_value=q,
    )
    for q in data.get("data", {})
    if q.get("symbol") in coins_select
]

pprint(coin_data)

kafka_keys = [c.kafka_key for c in coin_data]
pprint(kafka_keys)
# Out:
# [CoinData(kafka_key='BTC',
#           kafka_value={'circulating_supply': 19822912,
#                        'cmc_rank': 1,
#                        'date_added': '2010-07-13T00:00:00.000Z',
#                        'id': 1,
#                        'infinite_supply': False,
#                        'last_updated': '2025-02-11T19:32:00.000Z',
#                        'max_supply': 21000000,
#                        'name': 'Bitcoin',
#                        'num_market_pairs': 11931,
#                        'platform': None,
#                        'quote': {'USD': {'fully_diluted_market_cap': 1997722769053.91,
#                                          'last_updated': '2025-02-11T19:32:00.000Z',
#                                          'market_cap': 1885746792921.5217,
#                                          'market_cap_dominance': 60.3266,
#                                          'percent_change_1h': -0.64581622,
#                                          'percent_change_24h': -2.5375842,
#                                          'percent_change_30d': 0.44837373,
#                                          'percent_change_60d': -6.14327796,
#                                          'percent_change_7d': -5.36679904,
#                                          'percent_change_90d': 4.7418409,
#                                          'price': 95129.65566923375,
#                                          'tvl': None,
#                                          'volume_24h': 33047141317.35391,
#                                          'volume_change_24h': -25.2786}},
#                        'self_reported_circulating_supply': None,
#                        'self_reported_market_cap': None,
#                        'slug': 'bitcoin',
#                        'symbol': 'BTC',
#                        'tags': ['mineable',
#                                 'pow',
#                                 'sha-256',
#                                 'store-of-value',
#                                 'state-channel',
#                                 'coinbase-ventures-portfolio',
#                                 'three-arrows-capital-portfolio',
#                                 'polychain-capital-portfolio',
#                                 'binance-labs-portfolio',
#                                 'blockchain-capital-portfolio',
#                                 'boostvc-portfolio',
#                                 'cms-holdings-portfolio',
#                                 'dcg-portfolio',
#                                 'dragonfly-capital-portfolio',
#                                 'electric-capital-portfolio',
#                                 'fabric-ventures-portfolio',
#                                 'framework-ventures-portfolio',
#                                 'galaxy-digital-portfolio',
#                                 'huobi-capital-portfolio',
#                                 'alameda-research-portfolio',
#                                 'a16z-portfolio',
#                                 '1confirmation-portfolio',
#                                 'winklevoss-capital-portfolio',
#                                 'usv-portfolio',
#                                 'placeholder-ventures-portfolio',
#                                 'pantera-capital-portfolio',
#                                 'multicoin-capital-portfolio',
#                                 'paradigm-portfolio',
#                                 'bitcoin-ecosystem',
#                                 'ftx-bankruptcy-estate',
#                                 '2017-2018-alt-season'],
#                        'total_supply': 19822912,
#                        'tvl_ratio': None}),
#  CoinData(kafka_key='ETH',
#           kafka_value={'circulating_supply': 120540713.49245739,
#                        'cmc_rank': 2,
#                        'date_added': '2015-08-07T00:00:00.000Z',
#                        'id': 1027,
#                        'infinite_supply': True,
#                        'last_updated': '2025-02-11T19:33:00.000Z',
#                        'max_supply': None,
#                        'name': 'Ethereum',
#                        'num_market_pairs': 9923,
#                        'platform': None,
#                        'quote': {'USD': {'fully_diluted_market_cap': 313364736303.9,
#                                          'last_updated': '2025-02-11T19:33:00.000Z',
#                                          'market_cap': 313364736303.8974,
#                                          'market_cap_dominance': 10.0309,
#                                          'percent_change_1h': -0.99739495,
#                                          'percent_change_24h': -3.28536392,
#                                          'percent_change_30d': -20.7335589,
#                                          'percent_change_60d': -33.6828236,
#                                          'percent_change_7d': -8.78252167,
#                                          'percent_change_90d': -18.54325875,
#                                          'price': 2599.658880594776,
#                                          'tvl': None,
#                                          'volume_24h': 18550973938.481617,
#                                          'volume_change_24h': -16.0453}},
#                        'self_reported_circulating_supply': None,
#                        'self_reported_market_cap': None,
#                        'slug': 'ethereum',
#                        'symbol': 'ETH',
#                        'tags': ['pos',
#                                 'smart-contracts',
#                                 'ethereum-ecosystem',
#                                 'coinbase-ventures-portfolio',
#                                 'three-arrows-capital-portfolio',
#                                 'polychain-capital-portfolio',
#                                 'heco-ecosystem',
#                                 'binance-labs-portfolio',
#                                 'avalanche-ecosystem',
#                                 'solana-ecosystem',
#                                 'blockchain-capital-portfolio',
#                                 'boostvc-portfolio',
#                                 'cms-holdings-portfolio',
#                                 'dcg-portfolio',
#                                 'dragonfly-capital-portfolio',
#                                 'electric-capital-portfolio',
#                                 'fabric-ventures-portfolio',
#                                 'framework-ventures-portfolio',
#                                 'hashkey-capital-portfolio',
#                                 'kenetic-capital-portfolio',
#                                 'huobi-capital-portfolio',
#                                 'alameda-research-portfolio',
#                                 'a16z-portfolio',
#                                 '1confirmation-portfolio',
#                                 'winklevoss-capital-portfolio',
#                                 'usv-portfolio',
#                                 'placeholder-ventures-portfolio',
#                                 'pantera-capital-portfolio',
#                                 'multicoin-capital-portfolio',
#                                 'paradigm-portfolio',
#                                 'tezos-ecosystem',
#                                 'near-protocol-ecosystem',
#                                 'bnb-chain-ecosystem',
#                                 'velas-ecosystem',
#                                 'ethereum-pow-ecosystem',
#                                 'osmosis-ecosystem',
#                                 'layer-1',
#                                 'ftx-bankruptcy-estate',
#                                 'zksync-era-ecosystem',
#                                 'viction-ecosystem',
#                                 'klaytn-ecosystem',
#                                 'sora-ecosystem',
#                                 'rsk-rbtc-ecosystem',
#                                 'starknet-ecosystem'],
#                        'total_supply': 120540713.49245739,
#                        'tvl_ratio': None})]
# ['BTC', 'ETH']

# %% [markdown]
# ### Dataclass for consumer

# %%
@dataclass
class CoinQuote:
    symbol: str
    name: str
    last_updated: str
    price: float
    percent_change_1h: float


quotes = [
    CoinQuote(
        symbol=quote.kafka_value.get("symbol", ""),
        name=quote.kafka_value.get("name", ""),
        last_updated=quote.kafka_value.get("last_updated", ""),
        price=quote.kafka_value.get("quote", {}).get("USD", {}).get("price", ""),
        percent_change_1h=quote.kafka_value.get("quote", {})
        .get("USD", {})
        .get("percent_change_1h", ""),
    )
    for quote in coin_data
]

pprint(quotes)
# Out:
# [CoinQuote(symbol='BTC',
#            name='Bitcoin',
#            last_updated='2025-02-11T19:32:00.000Z',
#            price=95129.65566923375,
#            percent_change_1h=-0.64581622),
#  CoinQuote(symbol='ETH',
#            name='Ethereum',
#            last_updated='2025-02-11T19:33:00.000Z',
#            price=2599.658880594776,
#            percent_change_1h=-0.99739495)]
