# %%
data = {'coin_data': {'TRX': [{'circulating_supply': 86090671062.6711,
                        'cmc_rank': 10,
                        'date_added': '2017-09-13T00:00:00.000Z',
                        'id': 1958,
                        'infinite_supply': True,     
                        'is_active': 1,
                        'is_fiat': 0,
                        'last_updated': '2025-02-19T10:06:00.000Z',
                        'max_supply': None,
                        'name': 'TRON',
                        'num_market_pairs': 1119,    
                        'platform': None,
                        'quote': {'EUR': {'fully_diluted_market_cap': 20080836115.89984,
                                          'last_updated': '2025-02-19T10:05:05.000Z',
                                          'market_cap': 20080824694.122177,
                                          'market_cap_dominance': 0.6622,
                                          'percent_change_1h': 0.26338526,
                                          'percent_change_24h': 1.59013163,
                                          'percent_change_30d': 1.34790041,
                                          'percent_change_60d': -3.40602402,
                                          'percent_change_7d': 0.33801888,
                                          'percent_change_90d': 22.63893541,
                                          'price': 0.23325204050859377,
                                          'tvl': None,
                                          'volume_24h': 574274672.130291,
                                          'volume_change_24h': -5.8908}},
                        'self_reported_circulating_supply': None,
                        'self_reported_market_cap': None,
                        'slug': 'tron',
                        'symbol': 'TRX',
                        'total_supply': 86090720030.19646,
                        'tvl_ratio': None}],
               'XRP': [{'circulating_supply': 57818864895,
                        'cmc_rank': 3,
                        'date_added': '2013-08-04T00:00:00.000Z',
                        'id': 52,
                        'infinite_supply': False,    
                        'is_active': 1,
                        'is_fiat': 0,
                        'last_updated': '2025-02-19T10:06:00.000Z',
                        'max_supply': 100000000000,  
                        'name': 'XRP',
                        'num_market_pairs': 1534,    
                        'platform': None,
                        'quote': {'EUR': {'fully_diluted_market_cap': 246485230139.38843,
                                          'last_updated': '2025-02-19T10:05:05.000Z',
                                          'market_cap': 142514962200.42422,
                                          'market_cap_dominance': 4.6968,
                                          'percent_change_1h': 0.8103584,
                                          'percent_change_24h': -1.24154222,
                                          'percent_change_30d': -20.77658925,
                                          'percent_change_60d': 11.01278513,
                                          'percent_change_7d': 6.26165639,
                                          'percent_change_90d': 127.96861831,
                                          'price': 2.4648523013939085,
                                          'tvl': None,
                                          'volume_24h': 4622284288.981819,
                                          'volume_change_24h': 0.549}},
                        'self_reported_circulating_supply': None,
                        'self_reported_market_cap': None,
                        'slug': 'xrp',
                        'symbol': 'XRP',
                        'total_supply': 99986451428,
                        'tvl_ratio': None},
                       {'circulating_supply': 81597517,
                        'cmc_rank': 2261,
                        'date_added': '2023-08-11T16:17:34.000Z',
                        'id': 27809,
                        'infinite_supply': False,    
                        'is_active': 1,
                        'is_fiat': 0,
                        'last_updated': '2025-02-19T10:05:00.000Z',
                        'max_supply': None,
                        'name': 'HarryPotterObamaPacMan8Inu',
                        'num_market_pairs': 12,      
                        'platform': {'id': 1027,     
                                     'name': 'Ethereum',
                                     'slug': 'ethereum',
                                     'symbol': 'ETH',
                                     'token_address': '0x07E0EDf8ce600FB51d44F51E3348D77D67F298ae'},      
                        'quote': {'EUR': {'fully_diluted_market_cap': 437020.4216215204,
                                          'last_updated': '2025-02-19T10:05:05.000Z',
                                          'market_cap': 435970.4720255455,
                                          'market_cap_dominance': 0,
                                          'percent_change_1h': 0.80506215,
                                          'percent_change_24h': 0.36251227,
                                          'percent_change_30d': -48.88192098,
                                          'percent_change_60d': -44.92756439,
                                          'percent_change_7d': 9.97720032,
                                          'percent_change_90d': -49.79071189,
                                          'price': 0.0053429379723104265,
                                          'tvl': None,
                                          'volume_24h': 374.5366858439742,
                                          'volume_change_24h': -42.9443}},
                        'self_reported_circulating_supply': None,
                        'self_reported_market_cap': None,
                        'slug': 'harrypotterobamapacman8inu',
                        'symbol': 'XRP',
                        'tags': [{'category': 'INDUSTRY',
                                  'name': 'Memes',   
                                  'slug': 'memes'},  
                                 {'category': 'PLATFORM',
                                  'name': 'Ethereum Ecosystem',
                                  'slug': 'ethereum-ecosystem'}],
                        'total_supply': 81794028.70369202,
                        'tvl_ratio': None}]},        
 'rates_data': {'data': {'DKK': 7.458863,
                         'NOK': 11.621341,
                         'SEK': 11.184907,
                         'base': 'EUR'},
                'date': '2025-02-19'}}

# %%
from pprint import pprint


currency_sensitive_fields = ["price", "market_cap", "fully_diluted_market_cap", "volume_24h"]

def convert_from_base(base_record, symbol, rate):
    new_record = base_record.copy()
    new_record["base_currency"] = symbol

    for field in currency_sensitive_fields:
        new_record[field] = new_record[field] * rate

    return new_record

exchange_rates = data.get("rates_data").get("data")
exchange_rates_base = exchange_rates.pop("base")

def extract_records(data):
    records = []

    for item in data.get("coin_data").values():
        crypto_data = item[0]
        base_currency = next(iter(crypto_data.get("quote").keys()))
        quote_data = crypto_data.get("quote").get(base_currency)

        base_record = {
            "symbol" : crypto_data.get("symbol"),
            "last_updated" : quote_data.get("last_updated"),
            "base_currency" : base_currency,
            "price" : quote_data.get("price"),
            "circulating_supply" : crypto_data.get("circulating_supply"),
            "total_supply" : crypto_data.get("total_supply"),
            "market_cap" : quote_data.get("market_cap"),
            "market_cap_dominance" : quote_data.get("market_cap_dominance"),
            "fully_diluted_market_cap" : quote_data.get("fully_diluted_market_cap"),
            "percent_change_1h" : quote_data.get("percent_change_1h"),
            "percent_change_24h" : quote_data.get("percent_change_24h"),
            "percent_change_7d" : quote_data.get("percent_change_7d"),
            "percent_change_30d" : quote_data.get("percent_change_30d"),
            "percent_change_60d" : quote_data.get("percent_change_60d"),
            "percent_change_90d" : quote_data.get("percent_change_90d"),
            "volume_24h" : quote_data.get("volume_24h"),
            "volume_change_24h" : quote_data.get("volume_change_24h"),
            "cmc_rank" : crypto_data.get("cmc_rank"),
        }

        records.append(base_record)

        for symbol, rate in exchange_rates.items():
            records.append(convert_from_base(base_record, symbol, rate))

    return records


extract_records(data)
# Out:
# [{'symbol': 'TRX',
#   'last_updated': '2025-02-19T10:05:05.000Z',
#   'base_currency': 'EUR',
#   'price': 0.23325204050859377,
#   'circulating_supply': 86090671062.6711,
#   'total_supply': 86090720030.19646,
#   'market_cap': 20080824694.122177,
#   'market_cap_dominance': 0.6622,
#   'fully_diluted_market_cap': 20080836115.89984,
#   'percent_change_1h': 0.26338526,
#   'percent_change_24h': 1.59013163,
#   'percent_change_7d': 0.33801888,
#   'percent_change_30d': 1.34790041,
#   'percent_change_60d': -3.40602402,
#   'percent_change_90d': 22.63893541,
#   'volume_24h': 574274672.130291,
#   'volume_change_24h': -5.8908,
#   'cmc_rank': 10},
#  {'symbol': 'TRX',
#   'last_updated': '2025-02-19T10:05:05.000Z',
#   'base_currency': 'DKK',
#   'price': 1.7397950146240513,
#   'circulating_supply': 86090671062.6711,
#   'total_supply': 86090720030.19646,
#   'market_cap': 149780120320.4742,
#   'market_cap_dominance': 0.6622,
#   'fully_diluted_market_cap': 149780205513.94904,
# ...

# %%
from pprint import pprint

currency_sensitive_fields = ["price", "market_cap", "fully_diluted_market_cap", "volume_24h"]

def convert_from_base(base_record, symbol, rate):
    new_record = base_record.copy()
    new_record["base_currency"] = symbol

    for field in currency_sensitive_fields:
        new_record[field] = new_record[field] * rate

    return new_record

for symbol, rate in exchange_rates.items():
    pprint(convert_from_base(base_record, symbol, rate))
# Out:
# {'base_currency': 'DKK',
#  'circulating_supply': 57818864895,
#  'cmc_rank': 3,
#  'fully_diluted_market_cap': 1838499563133.1692,
#  'last_updated': '2025-02-19T10:05:05.000Z',
#  'market_cap': 1062999578503.1428,
#  'market_cap_dominance': 4.6968,
#  'percent_change_1h': 0.8103584,
#  'percent_change_24h': -1.24154222,
#  'percent_change_30d': -20.77658925,
#  'percent_change_60d': 11.01278513,
#  'percent_change_7d': 6.26165639,
#  'percent_change_90d': 127.96861831,
#  'price': 18.384995631331872,
#  'symbol': 'XRP',
#  'total_supply': 99986451428,
#  'volume_24h': 34476985258.5678,
#  'volume_change_24h': 0.549}
# {'base_currency': 'NOK',
#  'circulating_supply': 57818864895,
#  'cmc_rank': 3,
#  'fully_diluted_market_cap': 2864488910913.31,
#  'last_updated': '2025-02-19T10:05:05.000Z',
#  'market_cap': 1656214973333.2402,
#  'market_cap_dominance': 4.6968,
#  'percent_change_1h': 0.8103584,
#  'percent_change_24h': -1.24154222,
#  'percent_change_30d': -20.77658925,
# ...

# %%
base_record
# Out:
# {'symbol': 'XRP',
#  'last_updated': '2025-02-19T10:05:05.000Z',
#  'base_currency': 'EUR',
#  'price': 2.4648523013939085,
#  'circulating_supply': 57818864895,
#  'total_supply': 99986451428,
#  'market_cap': 142514962200.42422,
#  'market_cap_dominance': 4.6968,
#  'fully_diluted_market_cap': 246485230139.38843,
#  'percent_change_1h': 0.8103584,
#  'percent_change_24h': -1.24154222,
#  'percent_change_7d': 6.26165639,
#  'percent_change_30d': -20.77658925,
#  'percent_change_60d': 11.01278513,
#  'percent_change_90d': 127.96861831,
#  'volume_24h': 4622284288.981819,
#  'volume_change_24h': 0.549,
#  'cmc_rank': 3}

# %%
crypto_keys = list(data_crypto["data"]["TRX"][0].keys())

selected_crypto_keys = {
    'circulating_supply': 'The number of coins currently in circulation.',
    'cmc_rank': 'Cryptocurrencies rank based on market capitalization on CoinMarketCap',
    'date_added' : 'The date cryptocurrency was added to CoinMarketCap',
    'id': 'Unique identifier for cryprocurrency on CoinMarketCap',
    'last_updated': 'The last time this data was updated (UTC timestamp)',
    'max_supply': 'Maximum possible supply of the cryptocurrency (None = no fixed limit).',
    'name': 'The full name of the cryptocurrency ',
    'quote': 'Price and market data for cryptocurrency',
    'slug': 'A URL-friendly, unique identifier for the cryptocurrency.',
    'symbol': 'The abbreviated symbol for the cryptocurrency used on exchanges and in trading.',
    'total_supply': 'The total number of coins or tokens that have been created (minted) for that cryptocurrency, minus any coins that have been burned.',
}

selected_crypto_keys_list = list(selected_crypto_keys.keys())
selected_crypto_keys_list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 crypto_keys = list(data_crypto["data"]["TRX"][0].keys())
#       3 selected_crypto_keys = {
#       4     'circulating_supply': 'The number of coins currently in circulation.',
#       5     'cmc_rank': 'Cryptocurrencies rank based on market capitalization on CoinMarketCap',
#    (...)
#      14     'total_supply': 'The total number of coins or tokens that have been created (minted) for that cryptocurrency, minus any coins that have been burned.',
#      15 }
#      17 selected_crypto_keys_list = list(selected_crypto_keys.keys())
#
# NameError: name 'data_crypto' is not defined
